# %% [markdown]
# <table align="center">
#   <td align="center"><a target="_blank" href="https://colab.research.google.com/github/KhaledElTahan/DeepLearning/blob/master/Labs/lab3/Lab3.ipynb">
#         <img src="http://introtodeeplearning.com/images/colab/colab.png?v2.0"  style="padding-bottom:5px;" />Run in Google Colab</a></td>
# </table>

# %% [markdown]
# # Lab3: Convolutional Neural Network Use Cases

# %% [markdown]
# ![Simple CNN](https://github.com/KhaledElTahan/DeepLearning/blob/master/Labs/lab3/Cover.png?raw=1)

# %% [markdown]
# ## 3.1 Problem Statement

# %% [markdown]
# In this lab you will build several CNN models that check if a person is happy or not. You will use custom made CNN, and CNN use cases either pretrained or not, also you will apply layers freezing on pretrained CNNs and study all those modifications effect on the accuracy.

# %% [markdown]
# **IMPORTANT NOTE:** You have to change runtime type on Google Colab to GPU since this lab requires much computation resources and it will run very slowly on CPU (Default runtime type)

# %% [markdown]
# ## 3.2 Problem Details

# %% [markdown]
# ### 3.2.1 Packages & Utility Methods

# %%
import tensorflow as tf
import numpy as np

from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D
from tensorflow.keras.layers import AveragePooling2D, MaxPooling2D, Dropout, GlobalMaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD, Adam, RMSprop
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.imagenet_utils import preprocess_input
from tensorflow.keras.utils import plot_model
from tensorflow.keras import applications
import tensorflow.keras.backend as K
K.set_image_data_format('channels_last')

from IPython.display import SVG
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

import pydot
import h5py
import random
import requests

# %matplotlib inline

# %%
def download_file(file_url):
    file_r = requests.get(file_url, allow_redirects=True)
    open(file_url.rsplit('/', 1)[1], 'wb').write(file_r.content)

# %% [markdown]
# ### 3.2.2 Dataset Loading

# %% [markdown]
# #### Define method to download & load dataset

# %%
def load_dataset():
    download_file("https://raw.githubusercontent.com/KhaledElTahan/DeepLearning/master/Labs/lab3/lab3_train.h5")
    download_file("https://raw.githubusercontent.com/KhaledElTahan/DeepLearning/master/Labs/lab3/lab3_test.h5")

    path_to_train = "lab3_train.h5"
    path_to_test = "lab3_test.h5"

    train_dataset = h5py.File(path_to_train, "r")
    train_x = np.array(train_dataset['train_set_x'][:])
    train_y = np.array(train_dataset['train_set_y'][:])

    test_dataset = h5py.File(path_to_test, "r")
    test_x = np.array(test_dataset['test_set_x'][:])
    test_y = np.array(test_dataset['test_set_y'][:])

    # reshape y from (samples, ) to (1, samples)
    train_y = train_y.reshape((1, train_x.shape[0]))
    test_y = test_y.reshape((1, test_x.shape[0]))

    # transpose y
    train_y = train_y.T
    test_y = test_y.T

    return train_x, train_y, test_x, test_y

# %% [markdown]
# #### Define method to make simple preprocessing on the dataset

# %%
def preprocess_data():
    train_x, train_y, test_x, test_y = load_dataset()

    # Normalize image vectors
    train_x = train_x/255.
    test_x = test_x/255.

    print ("number of training examples = " + str(train_x.shape[0]))
    print ("number of test examples = " + str(test_x.shape[0]))

    print ("X_train shape: " + str(train_x.shape))
    print ("Y_train shape: " + str(train_y.shape))
    print ("X_test shape: " + str(test_x.shape))
    print ("Y_test shape: " + str(test_y.shape))

    return train_x, train_y, test_x, test_y

# %% [markdown]
# #### Get the preprocessed Data

# %%
train_x, train_y, test_x, test_y = preprocess_data()
# Out:
# number of training examples = 600
# number of test examples = 150
# X_train shape: (600, 64, 64, 3)
# Y_train shape: (600, 1)
# X_test shape: (150, 64, 64, 3)
# Y_test shape: (150, 1)

# %% [markdown]
# ### 3.2.3 Dataset Visualization

# %%
W_grid = 6
L_grid = 6

fig, axes = plt.subplots(L_grid, W_grid, figsize = (9,9))

axes = axes.ravel() # flaten the L_grid x W_grid matrix into L_grid * W_grid array

n_training = len(train_x) # get the length of the training dataset

for i in np.arange(0, W_grid * L_grid): # create evenly spaces variables 

    index = np.random.randint(0, n_training)
    axes[i].imshow(train_x[index])

    if train_y[index] == 1:
        axes[i].set_title("Happy", fontsize = 10)
    else:
        axes[i].set_title("Not Happy", fontsize = 10)
    axes[i].axis('off')

plt.subplots_adjust(hspace=0.4)

# %% [markdown]
# ### 3.2.4 Plot Utility Methods

# %% [markdown]
# The following code is used to plot accuracy and loss histories for each model experiment.

# %%
def plot(training_results, validation_results, results_type, model_name):
    fig = plt.figure(figsize=[8, 6])

    plt.plot(training_results, 'r', linewidth=3.0)
    plt.plot(validation_results, 'b', linewidth=3.0)
    plt.legend(['Training ' + results_type, 'Validation ' + results_type], fontsize=18)
    plt.xlabel('Epochs', fontsize=16)
    plt.ylabel(results_type, fontsize=16)
    plt.title(results_type + ' of ' + model_name, fontsize=16)


def plot_accuracy(history, model_name):
    plot(history.history['accuracy'], history.history['val_accuracy'], 'Accuracy', model_name)
    

def plot_loss(history, model_name):
    plot(history.history['loss'], history.history['val_loss'], 'Loss', model_name)

# %% [markdown]
# ### 3.2.5 Custom CNN Model

# %% [markdown]
# **TODO**: Build a custom CNN model to solve the problem.
#
# Model guidelines (You need to follow them):
#
# 1. [Input](https://keras.io/api/layers/core_layers/input/) Layer.
# 2. [ZeroPadding2D](https://keras.io/api/layers/reshaping_layers/zero_padding2d/) Layer.
# 3. [Conv2D](https://keras.io/api/layers/convolution_layers/convolution2d/) Layer.
# 4. [BatchNormalization](https://keras.io/api/layers/normalization_layers/batch_normalization/) Layer. Read [this article](https://kharshit.github.io/blog/2018/12/28/why-batch-normalization) for more about Batchnormalization.
# 5. Relu [Activation](https://keras.io/api/layers/core_layers/activation/).
# 6. [MaxPooling2D](https://keras.io/api/layers/pooling_layers/max_pooling2d/) Layer.
# 7. [Flatten](https://keras.io/api/layers/reshaping_layers/flatten/) Layer.
# 8. [Dense](https://keras.io/api/layers/core_layers/dense/) with Sigmoid Layer (one perceptrion).
#
# **Note**: If you made the required model, you can make other custom CNN models if you wish to further improve the accuracy, but in other code cells however.

# %%
def CustomCNN(input_shape, model_name = "CustomCNN"):
    """
    Implementation of the Custom CNN.
    Args:
        input_shape () shape of the images of the dataset
    Returns:
        model (Keras.Model): CNN Custom Model
        model_name (Str): The name of the model
    """
    
    ### START CODE HERE ###
    X_input = Input(input_shape)

    # Zero-Padding: pads the border of X_input with zeroes
    X = ZeroPadding2D((3, 3))(X_input)

    # CONV -> BN -> RELU Block applied to X
    '''TODO: Define the conv2d layer'''
    X = Conv2D(filters= 32, kernel_size=(5,5))(X)
    X = BatchNormalization(axis=3, name='bn0')(X)
    X = Activation('relu')(X)

    # MAXPOOL
    '''TODO: Define the maxpooling2d layer'''
    X = MaxPooling2D(pool_size=(2,2))(X)

    # FLATTEN X (means convert it to a vector) + FULLYCONNECTED (Dense)
    X = Flatten()(X)
    '''TODO: Define the dense layer'''
    Y = Dense(units= 1, activation='sigmoid')(X)

    # Create model. This creates your tensorflow.keras model instance, you'll use this instance to train/test the model.
    model = Model(inputs=X_input, outputs=Y)
    ### END CODE HERE ###
    
    return model, "Custom CNN"

# %% [markdown]
# ### 3.2.6 CNN Use Case No.1: VGG

# %% [markdown]
# ![VGG Architecture](https://github.com/KhaledElTahan/DeepLearning/blob/master/Labs/lab3/vgg.png?raw=1)

# %% [markdown]
# **Note**: this ia a show case to help you do the same with other use cases.
#
# **TODO**: Try different variations for VGG:
#
# 1. [VGG16](https://www.tensorflow.org/api_docs/python/tf/keras/applications/VGG16)
# 2. [VGG19](https://www.tensorflow.org/api_docs/python/tf/keras/applications/VGG19)
#
# **Note**: You will need to experiment all of them both pretrained (both with or without layers freezing) and also untrained.

# %%
def VGG(pretrained = True, input_shape = (64, 64, 3), model_name = "VGG16"):
    """
    Returns VGG Keras Model
    Args:
        pretrained (Bool): Whether get a pretrained model or not
        input_shape (Tuple): To create the input layer, should match the image resolution
        model_name (str): String to capture the model name
    Examples:
        VGG(True) -> Model, "Pretrained VGG16"
    """
    original_model_name = model_name
    if (pretrained):
        model_name = "Pretrained " + model_name
        if (original_model_name == "VGG16"):
          base_model = applications.vgg16.VGG16(weights='imagenet', include_top=False, input_shape=input_shape, pooling='none')
        else:
          base_model = applications.vgg19.VGG19(weights='imagenet', include_top=False, input_shape=input_shape, pooling='none')
    else:
        model_name = "Untrained " + model_name
        if (original_model_name == "VGG16"):
          base_model = applications.vgg16.VGG16(weights=None, include_top=False, input_shape=input_shape, pooling='none')
        else:
          base_model = applications.vgg19.VGG19(weights=None, include_top=False, input_shape=input_shape, pooling='none')

    return base_model, model_name

# %% [markdown]
# ### 3.2.7 CNN Use Case No.2: ResNet

# %% [markdown]
# ![VGG vs ResNet](https://github.com/KhaledElTahan/DeepLearning/blob/master/Labs/lab3/VGG_vs_ResNet.png?raw=1)

# %% [markdown]
# **TODO**: Follow the same style for the above mentioned VGG and experiment the following ResNets:
#
# 1. [ResNet50](https://www.tensorflow.org/api_docs/python/tf/keras/applications/ResNet50)
# 2. [ResNet50V2](https://www.tensorflow.org/api_docs/python/tf/keras/applications/ResNet50V2)
# 3. [ResNet101](https://www.tensorflow.org/api_docs/python/tf/keras/applications/ResNet101)
# 4. [ResNet101v2](https://www.tensorflow.org/api_docs/python/tf/keras/applications/ResNet101V2)
#
# **Note 1**: You will need to experiment all of them both pretrained (both with or without layers freezing) and also untrained.
#
# **Note 2**: For very deep networks like ResNet101, the size of the input might get reduced too much and an error might be produced, you shall fix this issue by either resizing input image (preferred) or by adding padding.

# %%
def ResNet(pretrained = True, input_shape = (64, 64, 3), model_name = "ResNet50"):
    """
    Returns ResNet Keras Model
    Args:
        pretrained (Bool): Whether get a pretrained model or not
        input_shape (Tuple): To create the input layer, should match the image resolution
        model_name (str): String to capture the model name
    Examples:
        ResNet(True) -> Model, "Pretrained ResNet50"
    """
    original_model_name = model_name
    if (pretrained):
        model_name = "Pretrained " + model_name
        '''TODO: Define the pretrained model using keras.applications'''
        if (original_model_name == "ResNet50"):
          base_model = applications.resnet50.ResNet50(weights='imagenet', include_top=False, input_shape=input_shape, pooling='none')
        elif (original_model_name == "ResNet50V2"):
          base_model = applications.ResNet50V2(weights='imagenet', include_top=False, input_shape=input_shape, pooling='none')
        elif (original_model_name == "ResNet101"):
          base_model = applications.ResNet101(weights='imagenet', include_top=False, input_shape=input_shape, pooling='none')
        else:
          base_model = applications.ResNet101V2(weights='imagenet', include_top=False, input_shape=input_shape, pooling='none')
        
    else:
        model_name = "Untrained " + model_name
        '''TODO: Define the pretrained model using keras.applications'''
        if (original_model_name == "ResNet50"):
          base_model = applications.resnet50.ResNet50(weights=None, include_top=False, input_shape=input_shape, pooling='none')
        elif (original_model_name == "ResNet50V2"):
          base_model = applications.ResNet50V2(weights=None, include_top=False, input_shape=input_shape, pooling='none')
        elif (original_model_name == "ResNet101"):
          base_model = applications.ResNet101(weights=None, include_top=False, input_shape=input_shape, pooling='none')
        else:
          base_model = applications.ResNet101V2(weights=None, include_top=False, input_shape=input_shape, pooling='none')

    return base_model, model_name

# %% [markdown]
# ### 3.2.8 CNN Use Case No.3: MobileNet

# %% [markdown]
# **TODO**: Select one application other than VGG or ResNet from [here](https://www.tensorflow.org/api_docs/python/tf/keras/applications) and implement it the same way you did with VGG & ResNet.
#
# **Note**: You will need to experiment it in both pretrained (both with or without layers freezing) and also untrained.

# %%
def CNN_App(pretrained = True, input_shape = (64, 64, 3), model_name = "MobileNet"):
    """
    Returns A Custom CNN Application Keras Model
    Args:
        pretrained (Bool): Whether get a pretrained model or not
        input_shape (Tuple): To create the input layer, should match the image resolution
        model_name (str): String to capture the model name
    Examples:
        CNN_App(True, (64, 64, 3), "Xception") -> Model, "Pretrained Xception"
    """
    if(pretrained):
        model_name = "Pretrained " + model_name
        '''TODO: Define the pretrained model using keras.applications'''
        base_model = applications.MobileNet(weights='imagenet', include_top=False, input_shape=input_shape, pooling='none')
    else:
        model_name = "Untrained " + model_name
        '''TODO: Define the untrained model using keras.applications'''
        base_model = applications.MobileNet(weights=None, include_top=False, input_shape=input_shape, pooling='none')

    return base_model, model_name

# %% [markdown]
# ### 3.2.9 Layers Freezing

# %% [markdown]
# The following utility method is used for layers freezing.

# %% [markdown]
# **TODO**: Experiment all the pretrained models with layers freezing using different number of frozen layers.
#
# **NOTE**: You will not change this method at all, the experimenting will take place in the test cases section below.

# %%
def freeze(model, number_of_frozen_layers):
    layers = model.layers

    layers = layers[:number_of_frozen_layers]

    for layer in layers:
        layer.trainable = False

    return model

# %% [markdown]
# ### 3.2.10 Make your models

# %% [markdown]
# Use the following utility method to make the model you desire.

# %%
def make_model(pretrained=True, freeze_layers=False, number_of_frozen_layers=0, model_selection="VGG"):
    """
    Use this method to create models
    Args:
      pretrained (Bool): Whether make the model pretrained or not, doesn't apply to custom CNN.
      freeze_layers (Bool): Whether apply layers freezing on pretrained networks or not.
      number_of_frozen_layers (int): Number of frozen layers.
      model_selection (Str): Must be exactly "Custom", or "VGG", or "ResNet" or anything else for CNN_App
    """

    input_shape = (64, 64, 3)

    if model_selection == "Custom":
        model, model_name = CustomCNN(input_shape)
    elif model_selection == "VGG":
        #model, model_name = VGG(pretrained, input_shape,"VGG16")
        model, model_name = VGG(pretrained, input_shape,"VGG19")
    elif model_selection == "ResNet":
        #model, model_name = ResNet(pretrained, input_shape,"ResNet50")
        #model, model_name = ResNet(pretrained, input_shape,"ResNet50V2")
        #model, model_name = ResNet(pretrained, input_shape,"ResNet101")
        model, model_name = ResNet(pretrained, input_shape,"ResNet101V2")
    else:
        model, model_name = CNN_App(pretrained, input_shape)

    if model_selection != "Custom":
        if freeze_layers:
            model = freeze(model, number_of_frozen_layers)
            model_name = model_name + " with " + str(number_of_frozen_layers) + " Frozen Layers"

        ## Add classification head for non custom models
        y = model.output
        y = Flatten()(y)
        y = Dense(256, activation='relu')(y)
        y = Dense(1, activation='sigmoid', name='fc')(y)

        model = Model(inputs=model.input, outputs=y)

    return model, model_name

# %% [markdown]
# ### 3.2.11 Testing model utility method

# %% [markdown]
# This is a generic method that will be used to test all the implemented models, a modular design allows you to experiment more clearly.

# %% [markdown]
# **TODO**:
#
# 1. Try different [optimizers](https://keras.io/api/optimizers/) and report their affect on the **results** and plots.
# 2. For each optimizer, try different learning rates and other hyperparameters (If applicable), and report the difference on the **results** and plots.
# 3. Try different [loss functions](https://keras.io/api/losses/), and report their affect on **accuracy** and plots.
#
# **Note**: You don't need to try different optimizers, rates & losses on all models, just find the best model with the current optimizers, rates & losses then try your experiments (changing optimizers, rates & losses) only on this model.

# %%
def test_model(model, model_name, epochs=10, print_summary=True, plot_results=True):
    '''TODO: Experiment with different optimizers, learning rates, and losses'''

    #opt = SGD(lr=0.0001, decay=1e-6, momentum=0.9, nesterov=True)
    opt = Adam(learning_rate=0.0001)
    #opt = RMSprop(learning_rate=0.0001)
    l =  'binary_crossentropy'
    #l = 'poisson'
    model.compile(optimizer=opt, loss=l, metrics=['accuracy'])

    if (print_summary):
        model.summary()

    hist = model.fit(train_x, train_y, validation_data = (test_x, test_y), verbose=1, epochs=epochs, batch_size=32)
    preds = model.evaluate(test_x, test_y, batch_size=32, verbose=1, sample_weight=None)

    print ("Validation Loss = " + str(preds[0]))
    print ("Validation Accuracy = " + str(preds[1]))

    if(plot_results):
        plot_loss(hist, model_name)
        plot_accuracy(hist, model_name)

# %% [markdown]
# ### 3.2.12 Create your model test cases.

# %% [markdown]
# **TODO**: Fill here all the test cases methods that you want to apply.
#
# Add methods (Untrained, pretrained & pretrained with freezing) for:
# 1. ResNet
# 2. CNN App
#
# **NOTE**: Those test cases, don't change use case types (i.e. you will need to change the VGG in VGG() method to VGG19 and re test again for example) and doesn't change the loss function nor the optimizer type.

# %%
def test_custom_CNN(epochs=20, print_summary=True, plot_results=True):
    model, model_name = make_model(False, False, 0, "Custom")
    test_model(model, model_name, epochs, print_summary, plot_results)

# %%
def test_untrained_VGG(epochs=20, print_summary=True, plot_results=True):
    model, model_name = make_model(False, False, 0, "VGG")
    test_model(model, model_name, epochs, print_summary, plot_results)

# %%
def test_pretrained_VGG(epochs=20, print_summary=True, plot_results=True):
    model, model_name = make_model(True, False, 0, "VGG")
    test_model(model, model_name, epochs, print_summary, plot_results)

# %%
def test_pretrained_layers_freezing_VGG(epochs=20, num_frozen_layers = 5, print_summary=True, plot_results=True):
    model, model_name = make_model(True, True, num_frozen_layers, "VGG")
    test_model(model, model_name, epochs, print_summary, plot_results)

# %%
def test_untrained_ResNet(epochs=20, print_summary=True, plot_results=True):
    model, model_name = make_model(False, False, 0, "ResNet")
    test_model(model, model_name, epochs, print_summary, plot_results)

# %%
def test_pretrained_ResNet(epochs=20, print_summary=True, plot_results=True):
    model, model_name = make_model(True, False, 0, "ResNet")
    test_model(model, model_name, epochs, print_summary, plot_results)

# %%
def test_pretrained_layers_freezing_ResNet(epochs=20, num_frozen_layers = 5, print_summary=True, plot_results=True):
    model, model_name = make_model(True, True, num_frozen_layers, "ResNet")
    test_model(model, model_name, epochs, print_summary, plot_results)

# %%
def test_untrained_MobileNet(epochs=20, print_summary=True, plot_results=True):
    model, model_name = make_model(False, False, 0, "MobileNet")
    test_model(model, model_name, epochs, print_summary, plot_results)

# %%
def test_pretrained_MobileNet(epochs=20, print_summary=True, plot_results=True):
    model, model_name = make_model(True, False, 0, "MobileNet")
    test_model(model, model_name, epochs, print_summary, plot_results)

# %%
def test_pretrained_layers_freezing_MobileNet(epochs=20, num_frozen_layers = 5, print_summary=True, plot_results=True):
    model, model_name = make_model(True, True, num_frozen_layers, "MobileNet")
    test_model(model, model_name, epochs, print_summary, plot_results)

# %% [markdown]
# ###  3.2.13 Test your models

# %% [markdown]
# **TODO**: Call all your defined methods for testing here.
#
# **Note**: You might want to go up to 1000 epochs for the untrained model if the validation accuracy is low.

# %%
test_custom_CNN(20)
# Out:
# Model: "model_42"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_43 (InputLayer)        [(None, 64, 64, 3)]       0
# _________________________________________________________________
# zero_padding2d_3 (ZeroPaddin (None, 70, 70, 3)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 66, 66, 32)        2432
# _________________________________________________________________
# bn0 (BatchNormalization)     (None, 66, 66, 32)        128
# _________________________________________________________________
# activation_3 (Activation)    (None, 66, 66, 32)        0
# _________________________________________________________________
# max_pooling2d_63 (MaxPooling (None, 33, 33, 32)        0
# _________________________________________________________________
# flatten_42 (Flatten)         (None, 34848)             0
# _________________________________________________________________
# dense_42 (Dense)             (None, 1)                 34849
# =================================================================
# Total params: 37,409
# Trainable params: 37,345
# Non-trainable params: 64
# _________________________________________________________________
# Epoch 1/20
# 19/19 [==============================] - 1s 25ms/step - loss: 0.8233 - accuracy: 0.5962 - val_loss: 0.8710 - val_accuracy: 0.6600
# Epoch 2/20
# 19/19 [==============================] - 0s 15ms/step - loss: 0.7429 - accuracy: 0.7950 - val_loss: 0.8601 - val_accuracy: 0.6400
# Epoch 3/20
# 19/19 [==============================] - 0s 15ms/step - loss: 0.6734 - accuracy: 0.8564 - val_loss: 0.8501 - val_accuracy: 0.6800
# Epoch 4/20
# 19/19 [==============================] - 0s 14ms/step - loss: 0.6447 - accuracy: 0.9006 - val_loss: 0.8364 - val_accuracy: 0.8200
# Epoch 5/20
# 19/19 [==============================] - 0s 14ms/step - loss: 0.6250 - accuracy: 0.9263 - val_loss: 0.8259 - val_accuracy: 0.7400
# Epoch 6/20
# 19/19 [==============================] - 0s 14ms/step - loss: 0.5838 - accuracy: 0.9023 - val_loss: 0.8127 - val_accuracy: 0.8133
# Epoch 7/20
# 19/19 [==============================] - 0s 14ms/step - loss: 0.6104 - accuracy: 0.9478 - val_loss: 0.8018 - val_accuracy: 0.9133
# Epoch 8/20
# 19/19 [==============================] - 0s 14ms/step - loss: 0.5810 - accuracy: 0.9608 - val_loss: 0.7908 - val_accuracy: 0.9267
# Epoch 9/20
# 19/19 [==============================] - 0s 13ms/step - loss: 0.5763 - accuracy: 0.9473 - val_loss: 0.7769 - val_accuracy: 0.9067
# Epoch 10/20
# 19/19 [==============================] - 0s 13ms/step - loss: 0.5490 - accuracy: 0.9510 - val_loss: 0.7671 - val_accuracy: 0.9400
# Epoch 11/20
# 19/19 [==============================] - 0s 13ms/step - loss: 0.5251 - accuracy: 0.9616 - val_loss: 0.7566 - val_accuracy: 0.9400
# Epoch 12/20
# 19/19 [==============================] - 0s 13ms/step - loss: 0.5671 - accuracy: 0.9704 - val_loss: 0.7467 - val_accuracy: 0.9533
# Epoch 13/20
# 19/19 [==============================] - 0s 13ms/step - loss: 0.5639 - accuracy: 0.9628 - val_loss: 0.7375 - val_accuracy: 0.9533
# Epoch 14/20
# 19/19 [==============================] - 0s 12ms/step - loss: 0.5787 - accuracy: 0.9841 - val_loss: 0.7283 - val_accuracy: 0.8733
# Epoch 15/20
# 19/19 [==============================] - 0s 14ms/step - loss: 0.5557 - accuracy: 0.9616 - val_loss: 0.7176 - val_accuracy: 0.9000
# Epoch 16/20
# 19/19 [==============================] - 0s 13ms/step - loss: 0.5364 - accuracy: 0.9714 - val_loss: 0.7082 - val_accuracy: 0.9600
# Epoch 17/20
# 19/19 [==============================] - 0s 13ms/step - loss: 0.5414 - accuracy: 0.9771 - val_loss: 0.6975 - val_accuracy: 0.9400
# Epoch 18/20
# 19/19 [==============================] - 0s 13ms/step - loss: 0.5779 - accuracy: 0.9710 - val_loss: 0.6899 - val_accuracy: 0.9267
# Epoch 19/20
# 19/19 [==============================] - 0s 13ms/step - loss: 0.5353 - accuracy: 0.9776 - val_loss: 0.6809 - val_accuracy: 0.9600
# Epoch 20/20
# 19/19 [==============================] - 0s 12ms/step - loss: 0.5063 - accuracy: 0.9775 - val_loss: 0.6739 - val_accuracy: 0.9667
# 5/5 [==============================] - 0s 5ms/step - loss: 0.6739 - accuracy: 0.9667
# Validation Loss = 0.6738725304603577
# Validation Accuracy = 0.9666666388511658

# %%
test_untrained_VGG(100)
# Out:
# Model: "model_39"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_40 (InputLayer)        [(None, 64, 64, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 64, 64, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 64, 64, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 32, 32, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 32, 32, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 32, 32, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 16, 16, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 16, 16, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 8, 8, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 8, 8, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten_39 (Flatten)         (None, 2048)              0
# _________________________________________________________________
# dense_39 (Dense)             (None, 256)               524544
# _________________________________________________________________
# fc (Dense)                   (None, 1)                 257
# =================================================================
# Total params: 20,549,185
# Trainable params: 20,549,185
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 19/19 [==============================] - 3s 85ms/step - loss: 0.8700 - accuracy: 0.5353 - val_loss: 0.8883 - val_accuracy: 0.4400
# Epoch 2/100
# 19/19 [==============================] - 1s 71ms/step - loss: 0.8490 - accuracy: 0.4713 - val_loss: 0.8882 - val_accuracy: 0.4400
# Epoch 3/100
# 19/19 [==============================] - 1s 70ms/step - loss: 0.8476 - accuracy: 0.4663 - val_loss: 0.8878 - val_accuracy: 0.5600
# Epoch 4/100
# 19/19 [==============================] - 1s 70ms/step - loss: 0.8354 - accuracy: 0.4585 - val_loss: 0.8878 - val_accuracy: 0.5600
# Epoch 5/100
# 19/19 [==============================] - 1s 72ms/step - loss: 0.8289 - accuracy: 0.4880 - val_loss: 0.8879 - val_accuracy: 0.5600
# Epoch 6/100
# 19/19 [==============================] - 1s 70ms/step - loss: 0.8558 - accuracy: 0.5160 - val_loss: 0.8886 - val_accuracy: 0.4400
# Epoch 7/100
# 19/19 [==============================] - 1s 71ms/step - loss: 0.8399 - accuracy: 0.4871 - val_loss: 0.8874 - val_accuracy: 0.5600
# Epoch 8/100
# 19/19 [==============================] - 1s 71ms/step - loss: 0.8538 - accuracy: 0.5345 - val_loss: 0.8853 - val_accuracy: 0.6400
# Epoch 9/100
# 19/19 [==============================] - 1s 71ms/step - loss: 0
100
# 19/19 [==============================] - 1s 73ms/step - loss: 0.4696 - accuracy: 0.9950 - val_loss: 0.7661 - val_accuracy: 0.9533
# Epoch 73/100
# 19/19 [==============================] - 1s 73ms/step - loss: 0.4870 - accuracy: 0.9998 - val_loss: 1.0471 - val_accuracy: 0.9333
# Epoch 74/100
# 19/19 [==============================] - 1s 73ms/step - loss: 0.5337 - accuracy: 0.9524 - val_loss: 0.6425 - val_accuracy: 0.9667
# Epoch 75/100
# 19/19 [==============================] - 1s 72ms/step - loss: 0.4994 - accuracy: 0.9991 - val_loss: 0.7319 - val_accuracy: 0.8933
# Epoch 76/100
# 19/19 [==============================] - 1s 73ms/step - loss: 0.4880 - accuracy: 0.9919 - val_loss: 0.7364 - val_accuracy: 0.9400
# Epoch 77/100
# 19/19 [==============================] - 1s 72ms/step - loss: 0.4953 - accuracy: 0.9960 - val_loss: 0.7415 - val_accuracy: 0.9600
# Epoch 78/100
# 19/19 [==============================] - 1s 73ms/step - loss: 0.5088 - accuracy: 0.9987 - val_loss: 0.6229 - val_accuracy: 0.9667
# Epoch 79/100
# 19/19 [==============================] - 1s 73ms/step - loss: 0.4889 - accuracy: 1.0000 - val_loss: 0.7232 - val_accuracy: 0.9667
# Epoch 80/100
# 19/19 [==============================] - 1s 73ms/step - loss: 0.4956 - accuracy: 0.9983 - val_loss: 0.7360 - val_accuracy: 0.9333
# Epoch 81/100
# 19/19 [==============================] - 1s 74ms/step - loss: 0.5032 - accuracy: 0.9993 - val_loss: 0.8029 - val_accuracy: 0.9533
# Epoch 82/100
# 19/19 [==============================] - 1s 74ms/step - loss: 0.4694 - accuracy: 0.9926 - val_loss: 0.7599 - val_accuracy: 0.9467
# Epoch 83/100
# 19/19 [==============================] - 1s 73ms/step - loss: 0.6964 - accuracy: 0.9472 - val_loss: 0.6630 - val_accuracy: 0.8933
# Epoch 84/100
# 19/19 [==============================] - 1s 73ms/step - loss: 0.5424 - accuracy: 0.9805 - val_loss: 0.6329 - val_accuracy: 0.9600
# Epoch 85/100
# 19/19 [==============================] - 1s 73ms/step - loss: 0.5201 - accuracy: 1.0000 - val_loss: 0.6553 - val_accuracy: 0.9733
# Epoch 86/100
# 19/19 [==============================] - 1s 73ms/step - loss: 0.4756 - accuracy: 1.0000 - val_loss: 0.6814 - val_accuracy: 0.9733
# Epoch 87/100
# 19/19 [==============================] - 1s 73ms/step - loss: 0.4743 - accuracy: 1.0000 - val_loss: 0.6863 - val_accuracy: 0.9733
# Epoch 88/100
# 19/19 [==============================] - 1s 73ms/step - loss: 0.4980 - accuracy: 1.0000 - val_loss: 0.6937 - val_accuracy: 0.9733
# Epoch 89/100
# 19/19 [==============================] - 1s 73ms/step - loss: 0.5200 - accuracy: 1.0000 - val_loss: 0.7039 - val_accuracy: 0.9667
# Epoch 90/100
# 19/19 [==============================] - 1s 72ms/step - loss: 0.5179 - accuracy: 1.0000 - val_loss: 0.7153 - val_accuracy: 0.9667
# Epoch 91/100
# 19/19 [==============================] - 1s 72ms/step - loss: 0.4840 - accuracy: 1.0000 - val_loss: 0.7266 - val_accuracy: 0.9667
# Epoch 92/100
# 19/19 [==============================] - 1s 73ms/step - loss: 0.5077 - accuracy: 1.0000 - val_loss: 0.7371 - val_accuracy: 0.9667
# Epoch 93/100
# 19/19 [==============================] - 1s 73ms/step - loss: 0.5074 - accuracy: 1.0000 - val_loss: 0.7465 - val_accuracy: 0.9600
# Epoch 94/100
# 19/19 [==============================] - 1s 72ms/step - loss: 0.5233 - accuracy: 1.0000 - val_loss: 0.7534 - val_accuracy: 0.9667
# Epoch 95/100
# 19/19 [==============================] - 1s 73ms/step - loss: 0.4722 - accuracy: 1.0000 - val_loss: 0.7625 - val_accuracy: 0.9600
# Epoch 96/100
# 19/19 [==============================] - 1s 74ms/step - loss: 0.4863 - accuracy: 1.0000 - val_loss: 0.7765 - val_accuracy: 0.9600
# Epoch 97/100
# 19/19 [==============================] - 1s 72ms/step - loss: 0.4998 - accuracy: 0.9942 - val_loss: 0.6535 - val_accuracy: 0.9200
# Epoch 98/100
# 19/19 [==============================] - 1s 74ms/step - loss: 0.5146 - accuracy: 0.9721 - val_loss: 0.9056 - val_accuracy: 0.9267
# Epoch 99/100
# 19/19 [==============================] - 1s 72ms/step - loss: 0.5275 - accuracy: 0.9796 - val_loss: 0.6687 - val_accuracy: 0.9533
# Epoch 100/100
# 19/19 [==============================] - 1s 72ms/step - loss: 0.5061 - accuracy: 1.0000 - val_loss: 0.6586 - val_accuracy: 0.9600
# 5/5 [==============================] - 0s 17ms/step - loss: 0.6586 - accuracy: 0.9600
# Validation Loss = 0.6586411595344543
# Validation Accuracy = 0.9599999785423279

# %%
test_pretrained_VGG(20)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# Model: "model_43"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_44 (InputLayer)        [(None, 64, 64, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 64, 64, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 64, 64, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 32, 32, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 32, 32, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 32, 32, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 16, 16, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 16, 16, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 8, 8, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 8, 8, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten_43 (Flatten)         (None, 2048)              0
# _________________________________________________________________
# dense_43 (Dense)             (None, 256)               524544
# _________________________________________________________________
# fc (Dense)                   (None, 1)                 257
# =================================================================
# Total params: 15,239,489
# Trainable params: 15,239,489
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 19/19 [==============================] - 7s 250ms/step - loss: 0.6569 - accuracy: 0.6419 - val_loss: 0.5991 - val_accuracy: 0.7467
# Epoch 2/20
# 19/19 [==============================] - 2s 111ms/step - loss: 0.5462 - accuracy: 0.8394 - val_loss: 0.4892 - val_accuracy: 0.8733
# Epoch 3/20
# 19/19 [==============================] - 2s 111ms/step - loss: 0.4340 - accuracy: 0.8943 - val_loss: 0.3939 - val_accuracy: 0.9267
# Epoch 4/20
# 19/19 [==============================] - 2s 110ms/step - loss: 0.3282 - accuracy: 0.9408 - val_loss: 0.3162 - val_accuracy: 0.9200
# Epoch 5/20
# 19/19 [==============================] - 2s 110ms/step - loss: 0.2576 - accuracy: 0.9588 - val_loss: 0.2460 - val_accuracy: 0.9533
# Epoch 6/20
# 19/19 [==============================] - 2s 111ms/step - loss: 0.1893 - accuracy: 0.9615 - val_loss: 0.1927 - val_accuracy: 0.9467
# Epoch 7/20
# 19/19 [==============================] - 2s 110ms/step - loss: 0.1392 - accuracy: 0.9806 - val_loss: 0.1549 - val_accuracy: 0.9667
# Epoch 8/20
# 19/19 [==============================] - 2s 110ms/step - loss: 0.1145 - accuracy: 0.9869 - val_loss: 0.1538 - val_accuracy: 0.9400
# Epoch 9/20
# 19/19 [==============================] - 2s 111ms/step - loss: 0.0872 - accuracy: 0.9865 - val_loss: 0.1286 - val_accuracy: 0.9667
# Epoch 10/20
# 19/19 [==============================] - 2s 110ms/step - loss: 0.0797 - accuracy: 0.9885 - val_loss: 0.1197 - val_accuracy: 0.9667
# Epoch 11/20
# 19/19 [==============================] - 2s 110ms/step - loss: 0.0596 - accuracy: 0.9908 - val_loss: 0.1171 - val_accuracy: 0.9533
# Epoch 12/20
# 19/19 [==============================] - 2s 111ms/step - loss: 0.0550 - accuracy: 0.9895 - val_loss: 0.0902 - val_accuracy: 0.9733
# Epoch 13/20
# 19/19 [==============================] - 2s 110ms/step - loss: 0.0481 - accuracy: 0.9931 - val_loss: 0.0856 - val_accuracy: 0.9733
# Epoch 14/20
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0413 - accuracy: 0.9977 - val_loss: 0.0854 - val_accuracy: 0.9733
# Epoch 15/20
# 19/19 [==============================] - 2s 110ms/step - loss: 0.0375 - accuracy: 0.9954 - val_loss: 0.0754 - val_accuracy: 0.9733
# Epoch 16/20
# 19/19 [==============================] - 2s 111ms/step - loss: 0.0361 - accuracy: 0.9964 - val_loss: 0.0800 - val_accuracy: 0.9800
# Epoch 17/20
# 19/19 [==============================] - 2s 111ms/step - loss: 0.0319 - accuracy: 0.9958 - val_loss: 0.0687 - val_accuracy: 0.9867
# Epoch 18/20
# 19/19 [==============================] - 2s 111ms/step - loss: 0.0216 - accuracy: 0.9977 - val_loss: 0.1417 - val_accuracy: 0.9267
# Epoch 19/20
# 19/19 [==============================] - 2s 112ms/step - loss: 0.0299 - accuracy: 0.9941 - val_loss: 0.0686 - val_accuracy: 0.9867
# Epoch 20/20
# 19/19 [==============================] - 2s 111ms/step - loss: 0.0164 - accuracy: 0.9985 - val_loss: 0.0686 - val_accuracy: 0.9867
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0686 - accuracy: 0.9867
# Validation Loss = 0.0685541182756424
# Validation Accuracy = 0.9866666793823242

# %%
test_pretrained_layers_freezing_VGG(20, 10)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step
# Model: "model_47"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_48 (InputLayer)        [(None, 64, 64, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 64, 64, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 64, 64, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 32, 32, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 32, 32, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 32, 32, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 16, 16, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 16, 16, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 8, 8, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 8, 8, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten_47 (Flatten)         (None, 2048)              0
# _________________________________________________________________
# dense_47 (Dense)             (None, 256)               524544
# _________________________________________________________________
# fc (Dense)                   (None, 1)                 257
# =================================================================
# Total params: 20,549,185
# Trainable params: 18,813,697
# Non-trainable params: 1,735,488
# _________________________________________________________________
# Epoch 1/20
# 19/19 [==============================] - 3s 120ms/step - loss: 0.6697 - accuracy: 0.5738 - val_loss: 0.5902 - val_accuracy: 0.7933
# Epoch 2/20
# 19/19 [==============================] - 2s 96ms/step - loss: 0.5567 - accuracy: 0.8071 - val_loss: 0.5139 - val_accuracy: 0.8467
# Epoch 3/20
# 19/19 [==============================] - 2s 97ms/step - loss: 0.4794 - accuracy: 0.8917 - val_loss: 0.4394 - val_accuracy: 0.8867
# Epoch 4/20
# 19/19 [==============================] - 2s 97ms/step - loss: 0.3793 - accuracy: 0.9155 - val_loss: 0.3589 - val_accuracy: 0.9200
# Epoch 5/20
# 19/19 [==============================] - 2s 97ms/step - loss: 0.2975 - accuracy: 0.9181 - val_loss: 0.2949 - val_accuracy: 0.9333
# Epoch 6/20
# 19/19 [==============================] - 2s 97ms/step - loss: 0.2348 - accuracy: 0.9487 - val_loss: 0.2363 - val_accuracy: 0.9333
# Epoch 7/20
# 19/19 [==============================] - 2s 98ms/step - loss: 0.1745 - accuracy: 0.9626 - val_loss: 0.2049 - val_accuracy: 0.9467
# Epoch 8/20
# 19/19 [==============================] - 2s 96ms/step - loss: 0.1487 - accuracy: 0.9595 - val_loss: 0.1757 - val_accuracy: 0.9400
# Epoch 9/20
# 19/19 [==============================] - 2s 98ms/step - loss: 0.1225 - accuracy: 0.9616 - val_loss: 0.1310 - val_accuracy: 0.9800
# Epoch 10/20
# 19/19 [==============================] - 2s 96ms/step - loss: 0.0871 - accuracy: 0.9815 - val_loss: 0.1101 - val_accuracy: 0.9800
# Epoch 11/20
# 19/19 [==============================] - 2s 96ms/step - loss: 0.0831 - accuracy: 0.9792 - val_loss: 0.1250 - val_accuracy: 0.9533
# Epoch 12/20
# 19/19 [==============================] - 2s 96ms/step - loss: 0.0590 - accuracy: 0.9860 - val_loss: 0.1036 - val_accuracy: 0.9600
# Epoch 13/20
# 19/19 [==============================] - 2s 96ms/step - loss: 0.0695 - accuracy: 0.9807 - val_loss: 0.0746 - val_accuracy: 0.9867
# Epoch 14/20
# 19/19 [==============================] - 2s 96ms/step - loss: 0.0563 - accuracy: 0.9896 - val_loss: 0.0666 - val_accuracy: 0.9867
# Epoch 15/20
# 19/19 [==============================] - 2s 97ms/step - loss: 0.0390 - accuracy: 0.9950 - val_loss: 0.1349 - val_accuracy: 0.9467
# Epoch 16/20
# 19/19 [==============================] - 2s 97ms/step - loss: 0.0571 - accuracy: 0.9831 - val_loss: 0.0609 - val_accuracy: 0.9867
# Epoch 17/20
# 19/19 [==============================] - 2s 97ms/step - loss: 0.0321 - accuracy: 0.9966 - val_loss: 0.0677 - val_accuracy: 0.9733
# Epoch 18/20
# 19/19 [==============================] - 2s 97ms/step - loss: 0.0230 - accuracy: 0.9983 - val_loss: 0.0564 - val_accuracy: 0.9800
# Epoch 19/20
# 19/19 [==============================] - 2s 96ms/step - loss: 0.0195 - accuracy: 0.9994 - val_loss: 0.0485 - val_accuracy: 0.9867
# Epoch 20/20
# 19/19 [==============================] - 2s 96ms/step - loss: 0.0204 - accuracy: 0.9986 - val_loss: 0.0532 - val_accuracy: 0.9867
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0532 - accuracy: 0.9867
# Validation Loss = 0.05321277305483818
# Validation Accuracy = 0.9866666793823242

# %%
test_untrained_ResNet(100)
# Out:
# Model: "model_23"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_24 (InputLayer)           [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 70, 70, 3)    0           input_24[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 32, 32, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 34, 34, 64)   0           conv1_conv[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 16, 16, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_bn (BatchNo (None, 16, 16, 64)   256         pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_relu (Activ (None, 16, 16, 64)   0           conv2_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 16, 16, 64)   4096        conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 16, 16, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_pad (ZeroPadding (None, 18, 18, 64)   0           conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 16, 16, 64)   36864       conv2_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 16, 16, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 16, 16, 256)  16640       conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 16, 16, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Add)          (None, 16, 16, 256)  0           conv2_block1_0_conv[0][0]
#                                                                  conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_bn (BatchNo (None, 16, 16, 256)  1024        conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_relu (Activ (None, 16, 16, 256)  0           conv2_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 16, 16, 64)   16384       conv2_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 16, 16, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_pad (ZeroPadding (None, 18, 18, 64)   0           conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 16, 16, 64)   36864       conv2_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 16, 16, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 16, 16, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Add)          (None, 16, 16, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_bn (BatchNo (None, 16, 16, 256)  1024        conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_relu (Activ (None, 16, 16, 256)  0           conv2_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 16, 16, 64)   16384       conv2_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 16, 16, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_pad (ZeroPadding (None, 18, 18, 64)   0           conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 8, 8, 64)     36864       conv2_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 8, 8, 64)     0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 8, 8, 256)    0           conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 8, 8, 256)    16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Add)          (None, 8, 8, 256)    0           max_pooling2d_12[0][0]
#                                                                  conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_bn (BatchNo (None, 8, 8, 256)    1024        conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_relu (Activ (None, 8, 8, 256)    0           conv3_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 8, 8, 128)    32768       conv3_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 8, 8, 128)    0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_pad (ZeroPadding (None, 10, 10, 128)  0           conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 8, 8, 128)    147456      conv3_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 8, 8, 128)    0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 8, 8, 512)    131584      conv3_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 8, 8, 512)    66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Add)          (None, 8, 8, 512)    0           conv3_block1_0_conv[0][0]
#                                                                  conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_bn (BatchNo (None, 8, 8, 512)    2048        conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_relu (Activ (None, 8, 8, 512)    0           conv3_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 8, 8, 128)    65536       conv3_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 8, 8, 128)    0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_pad (ZeroPadding (None, 10, 10, 128)  0           conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 8, 8, 128)    147456      conv3_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 8, 8, 128)    0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 8, 8, 512)    66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Add)          (None, 8, 8, 512)    0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_bn (BatchNo (None, 8, 8, 512)    2048        conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_relu (Activ (None, 8, 8, 512)    0           conv3_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 8, 8, 128)    65536       conv3_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 8, 8, 128)    0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_pad (ZeroPadding (None, 10, 10, 128)  0           conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 8, 8, 128)    147456      conv3_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 8, 8, 128)    0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 8, 8, 512)    66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Add)          (None, 8, 8, 512)    0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_bn (BatchNo (None, 8, 8, 512)    2048        conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_relu (Activ (None, 8, 8, 512)    0           conv3_block4_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 8, 8, 128)    65536       conv3_block4_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 8, 8, 128)    0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_pad (ZeroPadding (None, 10, 10, 128)  0           conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 4, 4, 128)    147456      conv3_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 4, 4, 128)    0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 4, 4, 512)    0           conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 4, 4, 512)    66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Add)          (None, 4, 4, 512)    0           max_pooling2d_13[0][0]
#                                                                  conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_bn (BatchNo (None, 4, 4, 512)    2048        conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_relu (Activ (None, 4, 4, 512)    0           conv4_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 4, 4, 256)    131072      conv4_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 4, 4, 256)    0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_pad (ZeroPadding (None, 6, 6, 256)    0           conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 4, 4, 256)    589824      conv4_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 4, 4, 256)    0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 4, 4, 1024)   525312      conv4_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 4, 4, 1024)   263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Add)          (None, 4, 4, 1024)   0           conv4_block1_0_conv[0][0]
#                                                                  conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_bn (BatchNo (None, 4, 4, 1024)   4096        conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_relu (Activ (None, 4, 4, 1024)   0           conv4_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 4, 4, 256)    262144      conv4_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 4, 4, 256)    0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_pad (ZeroPadding (None, 6, 6, 256)    0           conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 4, 4, 256)    589824      conv4_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 4, 4, 256)    0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 4, 4, 1024)   263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Add)          (None, 4, 4, 1024)   0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_bn (BatchNo (None, 4, 4, 1024)   4096        conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_relu (Activ (None, 4, 4, 1024)   0           conv4_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 4, 4, 256)    262144      conv4_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 4, 4, 256)    0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_pad (ZeroPadding (None, 6, 6, 256)    0           conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 4, 4, 256)    589824      conv4_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 4, 4, 256)    0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 4, 4, 1024)   263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Add)          (None, 4, 4, 1024)   0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_bn (BatchNo (None, 4, 4, 1024)   4096        conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_relu (Activ (None, 4, 4, 1024)   0           conv4_block4_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 4, 4, 256)    262144      conv4_block4_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 4, 4, 256)    0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_pad (ZeroPadding (None, 6, 6, 256)    0           conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 4, 4, 256)    589824      conv4_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 4, 4, 256)    0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 4, 4, 1024)   263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Add)          (None, 4, 4, 1024)   0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_preact_bn (BatchNo (None, 4, 4, 1024)   4096        conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_preact_relu (Activ (None, 4, 4, 1024)   0           conv4_block5_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 4, 4, 256)    262144      conv4_block5_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 4, 4, 256)    0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_pad (ZeroPadding (None, 6, 6, 256)    0           conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 4, 4, 256)    589824      conv4_block5_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 4, 4, 256)    0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 4, 4, 1024)   263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Add)          (None, 4, 4, 1024)   0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_preact_bn (BatchNo (None, 4, 4, 1024)   4096        conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_preact_relu (Activ (None, 4, 4, 1024)   0           conv4_block6_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 4, 4, 256)    262144      conv4_block6_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 4, 4, 256)    0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_pad (ZeroPadding (None, 6, 6, 256)    0           conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 4, 4, 256)    589824      conv4_block6_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 4, 4, 256)    0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 4, 4, 1024)   263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Add)          (None, 4, 4, 1024)   0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_preact_bn (BatchNo (None, 4, 4, 1024)   4096        conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv4_block7_preact_relu (Activ (None, 4, 4, 1024)   0           conv4_block7_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 4, 4, 256)    262144      conv4_block7_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (Activation (None, 4, 4, 256)    0           conv4_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_pad (ZeroPadding (None, 6, 6, 256)    0           conv4_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, 4, 4, 256)    589824      conv4_block7_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_relu (Activation (None, 4, 4, 256)    0           conv4_block7_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_3_conv (Conv2D)    (None, 4, 4, 1024)   263168      conv4_block7_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_out (Add)          (None, 4, 4, 1024)   0           conv4_block6_out[0][0]
#                                                                  conv4_block7_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_preact_bn (BatchNo (None, 4, 4, 1024)   4096        conv4_block7_out[0][0]
# __________________________________________________________________________________________________
# conv4_block8_preact_relu (Activ (None, 4, 4, 1024)   0           conv4_block8_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_conv (Conv2D)    (None, 4, 4, 256)    262144      conv4_block8_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_relu (Activation (None, 4, 4, 256)    0           conv4_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_pad (ZeroPadding (None, 6, 6, 256)    0           conv4_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, 4, 4, 256)    589824      conv4_block8_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_relu (Activation (None, 4, 4, 256)    0           conv4_block8_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_3_conv (Conv2D)    (None, 4, 4, 1024)   263168      conv4_block8_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_out (Add)          (None, 4, 4, 1024)   0           conv4_block7_out[0][0]
#                                                                  conv4_block8_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_preact_bn (BatchNo (None, 4, 4, 1024)   4096        conv4_block8_out[0][0]
# __________________________________________________________________________________________________
# conv4_block9_preact_relu (Activ (None, 4, 4, 1024)   0           conv4_block9_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_conv (Conv2D)    (None, 4, 4, 256)    262144      conv4_block9_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_relu (Activation (None, 4, 4, 256)    0           conv4_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_pad (ZeroPadding (None, 6, 6, 256)    0           conv4_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_conv (Conv2D)    (None, 4, 4, 256)    589824      conv4_block9_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_relu (Activation (None, 4, 4, 256)    0           conv4_block9_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_3_conv (Conv2D)    (None, 4, 4, 1024)   263168      conv4_block9_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_out (Add)          (None, 4, 4, 1024)   0           conv4_block8_out[0][0]
#                                                                  conv4_block9_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_preact_bn (BatchN (None, 4, 4, 1024)   4096        conv4_block9_out[0][0]
# __________________________________________________________________________________________________
# conv4_block10_preact_relu (Acti (None, 4, 4, 1024)   0           conv4_block10_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_conv (Conv2D)   (None, 4, 4, 256)    262144      conv4_block10_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_relu (Activatio (None, 4, 4, 256)    0           conv4_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_pad (ZeroPaddin (None, 6, 6, 256)    0           conv4_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_conv (Conv2D)   (None, 4, 4, 256)    589824      conv4_block10_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_relu (Activatio (None, 4, 4, 256)    0           conv4_block10_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      conv4_block10_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_out (Add)         (None, 4, 4, 1024)   0           conv4_block9_out[0][0]
#                                                                  conv4_block10_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_preact_bn (BatchN (None, 4, 4, 1024)   4096        conv4_block10_out[0][0]
# __________________________________________________________________________________________________
# conv4_block11_preact_relu (Acti (None, 4, 4, 1024)   0           conv4_block11_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_conv (Conv2D)   (None, 4, 4, 256)    262144      conv4_block11_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_relu (Activatio (None, 4, 4, 256)    0           conv4_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_pad (ZeroPaddin (None, 6, 6, 256)    0           conv4_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_conv (Conv2D)   (None, 4, 4, 256)    589824      conv4_block11_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_relu (Activatio (None, 4, 4, 256)    0           conv4_block11_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      conv4_block11_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_out (Add)         (None, 4, 4, 1024)   0           conv4_block10_out[0][0]
#                                                                  conv4_block11_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_preact_bn (BatchN (None, 4, 4, 1024)   4096        conv4_block11_out[0][0]
# __________________________________________________________________________________________________
# conv4_block12_preact_relu (Acti (None, 4, 4, 1024)   0           conv4_block12_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_conv (Conv2D)   (None, 4, 4, 256)    262144      conv4_block12_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_relu (Activatio (None, 4, 4, 256)    0           conv4_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_pad (ZeroPaddin (None, 6, 6, 256)    0           conv4_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_conv (Conv2D)   (None, 4, 4, 256)    589824      conv4_block12_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_relu (Activatio (None, 4, 4, 256)    0           conv4_block12_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      conv4_block12_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_out (Add)         (None, 4, 4, 1024)   0           conv4_block11_out[0][0]
#                                                                  conv4_block12_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_preact_bn (BatchN (None, 4, 4, 1024)   4096        conv4_block12_out[0][0]
# __________________________________________________________________________________________________
# conv4_block13_preact_relu (Acti (None, 4, 4, 1024)   0           conv4_block13_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block13_1_conv (Conv2D)   (None, 4, 4, 256)    262144      conv4_block13_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block13_1_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block13_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_1_relu (Activatio (None, 4, 4, 256)    0           conv4_block13_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_pad (ZeroPaddin (None, 6, 6, 256)    0           conv4_block13_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_conv (Conv2D)   (None, 4, 4, 256)    589824      conv4_block13_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block13_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_relu (Activatio (None, 4, 4, 256)    0           conv4_block13_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block13_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      conv4_block13_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block13_out (Add)         (None, 4, 4, 1024)   0           conv4_block12_out[0][0]
#                                                                  conv4_block13_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block14_preact_bn (BatchN (None, 4, 4, 1024)   4096        conv4_block13_out[0][0]
# ...
#                                                                  conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# post_bn (BatchNormalization)    (None, 2, 2, 2048)   8192        conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# post_relu (Activation)          (None, 2, 2, 2048)   0           post_bn[0][0]
# __________________________________________________________________________________________________
# flatten_23 (Flatten)            (None, 8192)         0           post_relu[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 256)          2097408     flatten_23[0][0]
# __________________________________________________________________________________________________
# fc (Dense)                      (None, 1)            257         dense_23[0][0]
# ==================================================================================================
# Total params: 44,724,225
# Trainable params: 44,626,561
# Non-trainable params: 97,664
# __________________________________________________________________________________________________
# Epoch 1/100
# 19/19 [==============================] - 19s 367ms/step - loss: 0.9872 - accuracy: 0.4690 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 2/100
# 19/19 [==============================] - 5s 263ms/step - loss: 1.0000 - accuracy: 0.5003 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 3/100
# 19/19 [==============================] - 5s 262ms/step - loss: 1.0000 - accuracy: 0.5258 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 4/100
# 19/19 [==============================] - 5s 263ms/step - loss: 1.0000 - accuracy: 0.4897 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 5/100
# 19/19 [==============================] - 5s 262ms/step - loss: 1.0000 - accuracy: 0.4679 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 6/100
# 19/19 [==============================] - 5s 263ms/step - loss: 1.0000 - accuracy: 0.5004 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 7/100
# 19/19 [==============================] - 5s 260ms/step - loss: 1.0000 - accuracy: 0.4874 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 8/100
# 19/19 [==============================] - 5s 261ms/step - loss: 1.0000 - accuracy: 0.4715 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 9/100
# 19/19 [==============================] - 5s 262ms/step - loss: 1.0000 - accuracy: 0.5028 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 10/100
# 19/19 [==============================] - 5s 261ms/step - loss: 1.0000 - accuracy: 0.4867 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 11/100
# 19/19 [==============================] - 5s 260ms/step - loss: 1.0000 - accuracy: 0.5024 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 12/100
# 19/19 [==============================] - 5s 261ms/step - loss: 1.0000 - accuracy: 0.4851 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 13/100
# 19/19 [==============================] - 5s 263ms/step - loss: 1.0000 - accuracy: 0.4924 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 14/100
# 19/19 [==============================] - 5s 263ms/step - loss: 1.0000 - accuracy: 0.4919 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 15/100
# 19/19 [==============================] - 5s 262ms/step - loss: 1.0000 - accuracy: 0.5186 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 16/100
# 19/19 [==============================] - 5s 262ms/step - loss: 1.0000 - accuracy: 0.5126 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 17/100
# 19/19 [==============================] - 5s 261ms/step - loss: 1.0000 - accuracy: 0.4972 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 18/100
# 19/19 [==============================] - 5s 262ms/step - loss: 1.0000 - accuracy: 0.4792 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 19/100
# 19/19 [==============================] - 5s 263ms/step - loss: 1.0000 - accuracy: 0.4767 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 20/100
# 19/19 [==============================] - 5s 260ms/step - loss: 1.0000 - accuracy: 0.4936 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 21/100
# 19/19 [==============================] - 5s 261ms/step - loss: 1.0000 - accuracy: 0.4756 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 22/100
# 19/19 [==============================] - 5s 262ms/step - loss: 1.0000 - accuracy: 0.4937 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 23/100
# 19/19 [==============================] - 5s 262ms/step - loss: 1.0000 - accuracy: 0.5069 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 24/100
# 19/19 [==============================] - 5s 261ms/step - loss: 1.0000 - accuracy: 0.4967 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 25/100
# 19/19 [==============================] - 5s 261ms/step - loss: 1.0000 - accuracy: 0.4942 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 26/100
# 19/19 [==============================] - 5s 261ms/step - loss: 1.0000 - accuracy: 0.4957 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 27/100
# 19/19 [==============================] - 5s 261ms/step - loss: 1.0000 - accuracy: 0.5346 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 28/100
# 19/19 [==============================] - 5s 263ms/step - loss: 1.0000 - accuracy: 0.4940 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 29/100
# 19/19 [==============================] - 5s 261ms/step - loss: 1.0000 - accuracy: 0.5287 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 30/100
# 19/19 [==============================] - 5s 262ms/step - loss: 1.0000 - accuracy: 0.4885 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 31/100
# 19/19 [==============================] - 5s 261ms/step - loss: 1.0000 - accuracy: 0.4829 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 32/100
# 19/19 [==============================] - 5s 259ms/step - loss: 1.0000 - accuracy: 0.4913 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 33/100
# 19/19 [==============================] - 5s 260ms/step - loss: 1.0000 - accuracy: 0.4705 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 34/100
# 19/19 [==============================] - 5s 259ms/step - loss: 1.0000 - accuracy: 0.5084 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 35/100
# 19/19 [==============================] - 5s 260ms/step - loss: 1.0000 - accuracy: 0.4795 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 36/100
# 19/19 [==============================] - 5s 262ms/step - loss: 1.0000 - accuracy: 0.4716 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 37/100
# 19/19 [==============================] - 5s 263ms/step - loss: 1.0000 - accuracy: 0.4745 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 38/100
# 19/19 [==============================] - 5s 261ms/step - loss: 1.0000 - accuracy: 0.4992 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 39/100
# 19/19 [==============================] - 5s 262ms/step - loss: 1.0000 - accuracy: 0.4863 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 40/100
# 19/19 [==============================] - 5s 259ms/step - loss: 1.0000 - accuracy: 0.4953 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 41/100
# 19/19 [==============================] - 5s 261ms/step - loss: 1.0000 - accuracy: 0.4685 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 42/100
# 19/19 [==============================] - 5s 262ms/step - loss: 1.0000 - accuracy: 0.4966 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 43/100
# 19/19 [==============================] - 5s 260ms/step - loss: 1.0000 - accuracy: 0.5406 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 44/100
# 19/19 [==============================] - 5s 261ms/step - loss: 1.0000 - accuracy: 0.4864 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 45/100
# 19/19 [==============================] - 5s 262ms/step - loss: 1.0000 - accuracy: 0.4774 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 46/100
# 19/19 [==============================] - 5s 264ms/step - loss: 1.0000 - accuracy: 0.4875 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 47/100
# 19/19 [==============================] - 5s 259ms/step - loss: 1.0000 - accuracy: 0.4881 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 48/100
# 19/19 [==============================] - 5s 259ms/step - loss: 1.0000 - accuracy: 0.4990 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 49/100
# 19/19 [==============================] - 5s 261ms/step - loss: 1.0000 - accuracy: 0.4642 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 50/100
# 19/19 [==============================] - 5s 262ms/step - loss: 1.0000 - accuracy: 0.5287 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 51/100
# 19/19 [==============================] - 5s 262ms/step - loss: 1.0000 - accuracy: 0.4700 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 52/100
# 19/19 [==============================] - 5s 260ms/step - loss: 1.0000 - accuracy: 0.5169 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 53/100
# 19/19 [==============================] - 5s 261ms/step - loss: 1.0000 - accuracy: 0.5118 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 54/100
# 19/19 [==============================] - 5s 260ms/step - loss: 1.0000 - accuracy: 0.4621 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 55/100
# 19/19 [==============================] - 5s 261ms/step - loss: 1.0000 - accuracy: 0.5149 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 56/100
# 19/19 [==============================] - 5s 263ms/step - loss: 1.0000 - accuracy: 0.5198 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 57/100
# 19/19 [==============================] - 5s 261ms/step - loss: 1.0000 - accuracy: 0.5033 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 58/100
# 19/19 [==============================] - 5s 262ms/step - loss: 1.0000 - accuracy: 0.5232 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 59/100
# 19/19 [==============================] - 5s 264ms/step - loss: 1.0000 - accuracy: 0.5086 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 60/100
# 19/19 [==============================] - 5s 261ms/step - loss: 1.0000 - accuracy: 0.5081 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 61/100
# 19/19 [==============================] - 5s 261ms/step - loss: 1.0000 - accuracy: 0.5236 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 62/100
# 19/19 [==============================] - 5s 264ms/step - loss: 1.0000 - accuracy: 0.4798 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 63/100
# 19/19 [==============================] - 5s 262ms/step - loss: 1.0000 - accuracy: 0.5123 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 64/100
# 19/19 [==============================] - 5s 263ms/step - loss: 1.0000 - accuracy: 0.5009 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 65/100
# 19/19 [==============================] - 5s 264ms/step - loss: 1.0000 - accuracy: 0.5256 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 66/100
# 19/19 [==============================] - 5s 263ms/step - loss: 1.0000 - accuracy: 0.4930 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 67/100
# 19/19 [==============================] - 5s 261ms/step - loss: 1.0000 - accuracy: 0.5236 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 68/100
# 19/19 [==============================] - 5s 262ms/step - loss: 1.0000 - accuracy: 0.5121 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 69/100
# 19/19 [==============================] - 5s 260ms/step - loss: 1.0000 - accuracy: 0.4856 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 70/100
# 19/19 [==============================] - 5s 262ms/step - loss: 1.0000 - accuracy: 0.5082 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 71/100
# 19/19 [==============================] - 5s 263ms/step - loss: 1.0000 - accuracy: 0.4666 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 72/100
# 19/19 [==============================] - 5s 263ms/step - loss: 1.0000 - accuracy: 0.5034 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 73/100
# 19/19 [==============================] - 5s 263ms/step - loss: 1.0000 - accuracy: 0.4882 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 74/100
# 19/19 [==============================] - 5s 264ms/step - loss: 1.0000 - accuracy: 0.5112 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 75/100
# 19/19 [==============================] - 5s 265ms/step - loss: 1.0000 - accuracy: 0.5052 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 76/100
# 19/19 [==============================] - 5s 261ms/step - loss: 1.0000 - accuracy: 0.4631 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 77/100
# 19/19 [==============================] - 5s 262ms/step - loss: 1.0000 - accuracy: 0.5070 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 78/100
# 19/19 [==============================] - 5s 264ms/step - loss: 1.0000 - accuracy: 0.4881 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 79/100
# 19/19 [==============================] - 5s 263ms/step - loss: 1.0000 - accuracy: 0.4835 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 80/100
# 19/19 [==============================] - 5s 260ms/step - loss: 1.0000 - accuracy: 0.5057 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 81/100
# 19/19 [==============================] - 5s 260ms/step - loss: 1.0000 - accuracy: 0.5299 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 82/100
# 19/19 [==============================] - 5s 260ms/step - loss: 1.0000 - accuracy: 0.5069 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 83/100
# 19/19 [==============================] - 5s 262ms/step - loss: 1.0000 - accuracy: 0.5127 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 84/100
# 19/19 [==============================] - 5s 260ms/step - loss: 1.0000 - accuracy: 0.5156 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 85/100
# 19/19 [==============================] - 5s 261ms/step - loss: 1.0000 - accuracy: 0.4967 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 86/100
# 19/19 [==============================] - 5s 262ms/step - loss: 1.0000 - accuracy: 0.5036 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 87/100
# 19/19 [==============================] - 5s 260ms/step - loss: 1.0000 - accuracy: 0.4865 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 88/100
# 19/19 [==============================] - 5s 262ms/step - loss: 1.0000 - accuracy: 0.4804 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 89/100
# 19/19 [==============================] - 5s 261ms/step - loss: 1.0000 - accuracy: 0.5039 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 90/100
# 19/19 [==============================] - 5s 259ms/step - loss: 1.0000 - accuracy: 0.4755 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 91/100
# 19/19 [==============================] - 5s 259ms/step - loss: 1.0000 - accuracy: 0.5080 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 92/100
# 19/19 [==============================] - 5s 259ms/step - loss: 1.0000 - accuracy: 0.5035 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 93/100
# 19/19 [==============================] - 5s 259ms/step - loss: 1.0000 - accuracy: 0.5038 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 94/100
# 19/19 [==============================] - 5s 260ms/step - loss: 1.0000 - accuracy: 0.5014 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 95/100
# 19/19 [==============================] - 5s 261ms/step - loss: 1.0000 - accuracy: 0.5005 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 96/100
# 19/19 [==============================] - 5s 260ms/step - loss: 1.0000 - accuracy: 0.5062 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 97/100
# 19/19 [==============================] - 5s 260ms/step - loss: 1.0000 - accuracy: 0.5026 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 98/100
# 19/19 [==============================] - 5s 260ms/step - loss: 1.0000 - accuracy: 0.4967 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 99/100
# 19/19 [==============================] - 5s 261ms/step - loss: 1.0000 - accuracy: 0.4729 - val_loss: 1.0000 - val_accuracy: 0.5600
# Epoch 100/100
# 19/19 [==============================] - 5s 259ms/step - loss: 1.0000 - accuracy: 0.4992 - val_loss: 1.0000 - val_accuracy: 0.5600
# 5/5 [==============================] - 0s 68ms/step - loss: 1.0000 - accuracy: 0.5600
# Validation Loss = 0.9999998807907104
# Validation Accuracy = 0.5600000023841858

# %%
test_pretrained_ResNet(20)
# Out:
# Model: "model_28"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_29 (InputLayer)           [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 70, 70, 3)    0           input_29[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 32, 32, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 34, 34, 64)   0           conv1_conv[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 16, 16, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_bn (BatchNo (None, 16, 16, 64)   256         pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_relu (Activ (None, 16, 16, 64)   0           conv2_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 16, 16, 64)   4096        conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 16, 16, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_pad (ZeroPadding (None, 18, 18, 64)   0           conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 16, 16, 64)   36864       conv2_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 16, 16, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 16, 16, 256)  16640       conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 16, 16, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Add)          (None, 16, 16, 256)  0           conv2_block1_0_conv[0][0]
#                                                                  conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_bn (BatchNo (None, 16, 16, 256)  1024        conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_relu (Activ (None, 16, 16, 256)  0           conv2_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 16, 16, 64)   16384       conv2_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 16, 16, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_pad (ZeroPadding (None, 18, 18, 64)   0           conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 16, 16, 64)   36864       conv2_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 16, 16, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 16, 16, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Add)          (None, 16, 16, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_bn (BatchNo (None, 16, 16, 256)  1024        conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_relu (Activ (None, 16, 16, 256)  0           conv2_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 16, 16, 64)   16384       conv2_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 16, 16, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_pad (ZeroPadding (None, 18, 18, 64)   0           conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 8, 8, 64)     36864       conv2_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 8, 8, 64)     0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_27 (MaxPooling2D) (None, 8, 8, 256)    0           conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 8, 8, 256)    16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Add)          (None, 8, 8, 256)    0           max_pooling2d_27[0][0]
#                                                                  conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_bn (BatchNo (None, 8, 8, 256)    1024        conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_relu (Activ (None, 8, 8, 256)    0           conv3_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 8, 8, 128)    32768       conv3_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 8, 8, 128)    0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_pad (ZeroPadding (None, 10, 10, 128)  0           conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 8, 8, 128)    147456      conv3_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 8, 8, 128)    0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 8, 8, 512)    131584      conv3_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 8, 8, 512)    66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Add)          (None, 8, 8, 512)    0           conv3_block1_0_conv[0][0]
#                                                                  conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_bn (BatchNo (None, 8, 8, 512)    2048        conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_relu (Activ (None, 8, 8, 512)    0           conv3_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 8, 8, 128)    65536       conv3_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 8, 8, 128)    0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_pad (ZeroPadding (None, 10, 10, 128)  0           conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 8, 8, 128)    147456      conv3_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 8, 8, 128)    0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 8, 8, 512)    66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Add)          (None, 8, 8, 512)    0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_bn (BatchNo (None, 8, 8, 512)    2048        conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_relu (Activ (None, 8, 8, 512)    0           conv3_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 8, 8, 128)    65536       conv3_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 8, 8, 128)    0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_pad (ZeroPadding (None, 10, 10, 128)  0           conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 8, 8, 128)    147456      conv3_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 8, 8, 128)    0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 8, 8, 512)    66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Add)          (None, 8, 8, 512)    0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_bn (BatchNo (None, 8, 8, 512)    2048        conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_relu (Activ (None, 8, 8, 512)    0           conv3_block4_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 8, 8, 128)    65536       conv3_block4_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 8, 8, 128)    0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_pad (ZeroPadding (None, 10, 10, 128)  0           conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 4, 4, 128)    147456      conv3_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 4, 4, 128)    0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_28 (MaxPooling2D) (None, 4, 4, 512)    0           conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 4, 4, 512)    66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Add)          (None, 4, 4, 512)    0           max_pooling2d_28[0][0]
#                                                                  conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_bn (BatchNo (None, 4, 4, 512)    2048        conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_relu (Activ (None, 4, 4, 512)    0           conv4_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 4, 4, 256)    131072      conv4_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 4, 4, 256)    0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_pad (ZeroPadding (None, 6, 6, 256)    0           conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 4, 4, 256)    589824      conv4_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 4, 4, 256)    0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 4, 4, 1024)   525312      conv4_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 4, 4, 1024)   263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Add)          (None, 4, 4, 1024)   0           conv4_block1_0_conv[0][0]
#                                                                  conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_bn (BatchNo (None, 4, 4, 1024)   4096        conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_relu (Activ (None, 4, 4, 1024)   0           conv4_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 4, 4, 256)    262144      conv4_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 4, 4, 256)    0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_pad (ZeroPadding (None, 6, 6, 256)    0           conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 4, 4, 256)    589824      conv4_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 4, 4, 256)    0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 4, 4, 1024)   263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Add)          (None, 4, 4, 1024)   0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_bn (BatchNo (None, 4, 4, 1024)   4096        conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_relu (Activ (None, 4, 4, 1024)   0           conv4_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 4, 4, 256)    262144      conv4_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 4, 4, 256)    0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_pad (ZeroPadding (None, 6, 6, 256)    0           conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 4, 4, 256)    589824      conv4_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 4, 4, 256)    0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 4, 4, 1024)   263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Add)          (None, 4, 4, 1024)   0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_bn (BatchNo (None, 4, 4, 1024)   4096        conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_relu (Activ (None, 4, 4, 1024)   0           conv4_block4_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 4, 4, 256)    262144      conv4_block4_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 4, 4, 256)    0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_pad (ZeroPadding (None, 6, 6, 256)    0           conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 4, 4, 256)    589824      conv4_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 4, 4, 256)    0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 4, 4, 1024)   263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Add)          (None, 4, 4, 1024)   0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_preact_bn (BatchNo (None, 4, 4, 1024)   4096        conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_preact_relu (Activ (None, 4, 4, 1024)   0           conv4_block5_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 4, 4, 256)    262144      conv4_block5_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 4, 4, 256)    0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_pad (ZeroPadding (None, 6, 6, 256)    0           conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 4, 4, 256)    589824      conv4_block5_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 4, 4, 256)    0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 4, 4, 1024)   263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Add)          (None, 4, 4, 1024)   0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_preact_bn (BatchNo (None, 4, 4, 1024)   4096        conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_preact_relu (Activ (None, 4, 4, 1024)   0           conv4_block6_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 4, 4, 256)    262144      conv4_block6_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 4, 4, 256)    0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_pad (ZeroPadding (None, 6, 6, 256)    0           conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 4, 4, 256)    589824      conv4_block6_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 4, 4, 256)    0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 4, 4, 1024)   263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Add)          (None, 4, 4, 1024)   0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_preact_bn (BatchNo (None, 4, 4, 1024)   4096        conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv4_block7_preact_relu (Activ (None, 4, 4, 1024)   0           conv4_block7_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 4, 4, 256)    262144      conv4_block7_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (Activation (None, 4, 4, 256)    0           conv4_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_pad (ZeroPadding (None, 6, 6, 256)    0           conv4_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, 4, 4, 256)    589824      conv4_block7_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_relu (Activation (None, 4, 4, 256)    0           conv4_block7_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_3_conv (Conv2D)    (None, 4, 4, 1024)   263168      conv4_block7_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_out (Add)          (None, 4, 4, 1024)   0           conv4_block6_out[0][0]
#                                                                  conv4_block7_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_preact_bn (BatchNo (None, 4, 4, 1024)   4096        conv4_block7_out[0][0]
# __________________________________________________________________________________________________
# conv4_block8_preact_relu (Activ (None, 4, 4, 1024)   0           conv4_block8_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_conv (Conv2D)    (None, 4, 4, 256)    262144      conv4_block8_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_relu (Activation (None, 4, 4, 256)    0           conv4_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_pad (ZeroPadding (None, 6, 6, 256)    0           conv4_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, 4, 4, 256)    589824      conv4_block8_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_relu (Activation (None, 4, 4, 256)    0           conv4_block8_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_3_conv (Conv2D)    (None, 4, 4, 1024)   263168      conv4_block8_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_out (Add)          (None, 4, 4, 1024)   0           conv4_block7_out[0][0]
#                                                                  conv4_block8_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_preact_bn (BatchNo (None, 4, 4, 1024)   4096        conv4_block8_out[0][0]
# __________________________________________________________________________________________________
# conv4_block9_preact_relu (Activ (None, 4, 4, 1024)   0           conv4_block9_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_conv (Conv2D)    (None, 4, 4, 256)    262144      conv4_block9_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_relu (Activation (None, 4, 4, 256)    0           conv4_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_pad (ZeroPadding (None, 6, 6, 256)    0           conv4_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_conv (Conv2D)    (None, 4, 4, 256)    589824      conv4_block9_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_relu (Activation (None, 4, 4, 256)    0           conv4_block9_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_3_conv (Conv2D)    (None, 4, 4, 1024)   263168      conv4_block9_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_out (Add)          (None, 4, 4, 1024)   0           conv4_block8_out[0][0]
#                                                                  conv4_block9_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_preact_bn (BatchN (None, 4, 4, 1024)   4096        conv4_block9_out[0][0]
# __________________________________________________________________________________________________
# conv4_block10_preact_relu (Acti (None, 4, 4, 1024)   0           conv4_block10_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_conv (Conv2D)   (None, 4, 4, 256)    262144      conv4_block10_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_relu (Activatio (None, 4, 4, 256)    0           conv4_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_pad (ZeroPaddin (None, 6, 6, 256)    0           conv4_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_conv (Conv2D)   (None, 4, 4, 256)    589824      conv4_block10_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_relu (Activatio (None, 4, 4, 256)    0           conv4_block10_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      conv4_block10_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_out (Add)         (None, 4, 4, 1024)   0           conv4_block9_out[0][0]
#                                                                  conv4_block10_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_preact_bn (BatchN (None, 4, 4, 1024)   4096        conv4_block10_out[0][0]
# __________________________________________________________________________________________________
# conv4_block11_preact_relu (Acti (None, 4, 4, 1024)   0           conv4_block11_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_conv (Conv2D)   (None, 4, 4, 256)    262144      conv4_block11_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_relu (Activatio (None, 4, 4, 256)    0           conv4_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_pad (ZeroPaddin (None, 6, 6, 256)    0           conv4_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_conv (Conv2D)   (None, 4, 4, 256)    589824      conv4_block11_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_relu (Activatio (None, 4, 4, 256)    0           conv4_block11_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      conv4_block11_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_out (Add)         (None, 4, 4, 1024)   0           conv4_block10_out[0][0]
#                                                                  conv4_block11_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_preact_bn (BatchN (None, 4, 4, 1024)   4096        conv4_block11_out[0][0]
# __________________________________________________________________________________________________
# conv4_block12_preact_relu (Acti (None, 4, 4, 1024)   0           conv4_block12_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_conv (Conv2D)   (None, 4, 4, 256)    262144      conv4_block12_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_relu (Activatio (None, 4, 4, 256)    0           conv4_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_pad (ZeroPaddin (None, 6, 6, 256)    0           conv4_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_conv (Conv2D)   (None, 4, 4, 256)    589824      conv4_block12_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_relu (Activatio (None, 4, 4, 256)    0           conv4_block12_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      conv4_block12_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_out (Add)         (None, 4, 4, 1024)   0           conv4_block11_out[0][0]
#                                                                  conv4_block12_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_preact_bn (BatchN (None, 4, 4, 1024)   4096        conv4_block12_out[0][0]
# __________________________________________________________________________________________________
# conv4_block13_preact_relu (Acti (None, 4, 4, 1024)   0           conv4_block13_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block13_1_conv (Conv2D)   (None, 4, 4, 256)    262144      conv4_block13_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block13_1_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block13_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_1_relu (Activatio (None, 4, 4, 256)    0           conv4_block13_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_pad (ZeroPaddin (None, 6, 6, 256)    0           conv4_block13_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_conv (Conv2D)   (None, 4, 4, 256)    589824      conv4_block13_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block13_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_relu (Activatio (None, 4, 4, 256)    0           conv4_block13_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block13_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      conv4_block13_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block13_out (Add)         (None, 4, 4, 1024)   0           conv4_block12_out[0][0]
#                                                                  conv4_block13_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block14_preact_bn (BatchN (None, 4, 4, 1024)   4096        conv4_block13_out[0][0]
# ...
# conv4_block22_preact_bn (BatchN (None, 4, 4, 1024)   4096        conv4_block21_out[0][0]
# __________________________________________________________________________________________________
# conv4_block22_preact_relu (Acti (None, 4, 4, 1024)   0           conv4_block22_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block22_1_conv (Conv2D)   (None, 4, 4, 256)    262144      conv4_block22_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block22_1_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block22_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block22_1_relu (Activatio (None, 4, 4, 256)    0           conv4_block22_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block22_2_pad (ZeroPaddin (None, 6, 6, 256)    0           conv4_block22_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block22_2_conv (Conv2D)   (None, 4, 4, 256)    589824      conv4_block22_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block22_2_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block22_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block22_2_relu (Activatio (None, 4, 4, 256)    0           conv4_block22_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block22_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      conv4_block22_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block22_out (Add)         (None, 4, 4, 1024)   0           conv4_block21_out[0][0]
#                                                                  conv4_block22_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block23_preact_bn (BatchN (None, 4, 4, 1024)   4096        conv4_block22_out[0][0]
# __________________________________________________________________________________________________
# conv4_block23_preact_relu (Acti (None, 4, 4, 1024)   0           conv4_block23_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block23_1_conv (Conv2D)   (None, 4, 4, 256)    262144      conv4_block23_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block23_1_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block23_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block23_1_relu (Activatio (None, 4, 4, 256)    0           conv4_block23_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block23_2_pad (ZeroPaddin (None, 6, 6, 256)    0           conv4_block23_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block23_2_conv (Conv2D)   (None, 2, 2, 256)    589824      conv4_block23_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block23_2_bn (BatchNormal (None, 2, 2, 256)    1024        conv4_block23_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block23_2_relu (Activatio (None, 2, 2, 256)    0           conv4_block23_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_29 (MaxPooling2D) (None, 2, 2, 1024)   0           conv4_block22_out[0][0]
# __________________________________________________________________________________________________
# conv4_block23_3_conv (Conv2D)   (None, 2, 2, 1024)   263168      conv4_block23_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block23_out (Add)         (None, 2, 2, 1024)   0           max_pooling2d_29[0][0]
#                                                                  conv4_block23_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_preact_bn (BatchNo (None, 2, 2, 1024)   4096        conv4_block23_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_preact_relu (Activ (None, 2, 2, 1024)   0           conv5_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 2, 2, 512)    524288      conv5_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 2, 2, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_pad (ZeroPadding (None, 4, 4, 512)    0           conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 2, 2, 512)    2359296     conv5_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 2, 2, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 2, 2, 2048)   2099200     conv5_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 2, 2, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Add)          (None, 2, 2, 2048)   0           conv5_block1_0_conv[0][0]
#                                                                  conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_preact_bn (BatchNo (None, 2, 2, 2048)   8192        conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_preact_relu (Activ (None, 2, 2, 2048)   0           conv5_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 2, 2, 512)    1048576     conv5_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 2, 2, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_pad (ZeroPadding (None, 4, 4, 512)    0           conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 2, 2, 512)    2359296     conv5_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 2, 2, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 2, 2, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Add)          (None, 2, 2, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_bn (BatchNo (None, 2, 2, 2048)   8192        conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_relu (Activ (None, 2, 2, 2048)   0           conv5_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 2, 2, 512)    1048576     conv5_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 2, 2, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_pad (ZeroPadding (None, 4, 4, 512)    0           conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 2, 2, 512)    2359296     conv5_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 2, 2, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 2, 2, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Add)          (None, 2, 2, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# post_bn (BatchNormalization)    (None, 2, 2, 2048)   8192        conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# post_relu (Activation)          (None, 2, 2, 2048)   0           post_bn[0][0]
# __________________________________________________________________________________________________
# flatten_28 (Flatten)            (None, 8192)         0           post_relu[0][0]
# __________________________________________________________________________________________________
# dense_28 (Dense)                (None, 256)          2097408     flatten_28[0][0]
# __________________________________________________________________________________________________
# fc (Dense)                      (None, 1)            257         dense_28[0][0]
# ==================================================================================================
# Total params: 44,724,225
# Trainable params: 44,626,561
# Non-trainable params: 97,664
# __________________________________________________________________________________________________
# Epoch 1/20
# 19/19 [==============================] - 19s 374ms/step - loss: 0.6188 - accuracy: 0.6671 - val_loss: 0.8092 - val_accuracy: 0.5800
# Epoch 2/20
# 19/19 [==============================] - 5s 263ms/step - loss: 0.1863 - accuracy: 0.9191 - val_loss: 0.6747 - val_accuracy: 0.7000
# Epoch 3/20
# 19/19 [==============================] - 5s 264ms/step - loss: 0.0792 - accuracy: 0.9727 - val_loss: 0.4919 - val_accuracy: 0.8267
# Epoch 4/20
# 19/19 [==============================] - 5s 264ms/step - loss: 0.0710 - accuracy: 0.9751 - val_loss: 0.7630 - val_accuracy: 0.8200
# Epoch 5/20
# 19/19 [==============================] - 5s 262ms/step - loss: 0.1457 - accuracy: 0.9533 - val_loss: 0.3513 - val_accuracy: 0.8933
# Epoch 6/20
# 19/19 [==============================] - 5s 263ms/step - loss: 0.0979 - accuracy: 0.9686 - val_loss: 0.4533 - val_accuracy: 0.8933
# Epoch 7/20
# 19/19 [==============================] - 5s 262ms/step - loss: 0.0230 - accuracy: 0.9917 - val_loss: 0.2632 - val_accuracy: 0.9267
# Epoch 8/20
# 19/19 [==============================] - 5s 263ms/step - loss: 0.0235 - accuracy: 0.9936 - val_loss: 0.1464 - val_accuracy: 0.9400
# Epoch 9/20
# 19/19 [==============================] - 5s 264ms/step - loss: 0.0127 - accuracy: 0.9974 - val_loss: 0.1175 - val_accuracy: 0.9667
# Epoch 10/20
# 19/19 [==============================] - 5s 264ms/step - loss: 0.0147 - accuracy: 0.9949 - val_loss: 0.1008 - val_accuracy: 0.9733
# Epoch 11/20
# 19/19 [==============================] - 5s 263ms/step - loss: 0.0182 - accuracy: 0.9967 - val_loss: 0.1239 - val_accuracy: 0.9800
# Epoch 12/20
# 19/19 [==============================] - 5s 262ms/step - loss: 0.0101 - accuracy: 0.9940 - val_loss: 0.0946 - val_accuracy: 0.9800
# Epoch 13/20
# 19/19 [==============================] - 5s 263ms/step - loss: 0.0369 - accuracy: 0.9904 - val_loss: 0.0881 - val_accuracy: 0.9733
# Epoch 14/20
# 19/19 [==============================] - 5s 261ms/step - loss: 0.0280 - accuracy: 0.9888 - val_loss: 0.0829 - val_accuracy: 0.9867
# Epoch 15/20
# 19/19 [==============================] - 5s 262ms/step - loss: 0.0066 - accuracy: 0.9986 - val_loss: 0.1081 - val_accuracy: 0.9733
# Epoch 16/20
# 19/19 [==============================] - 5s 263ms/step - loss: 0.0225 - accuracy: 0.9945 - val_loss: 0.0282 - val_accuracy: 0.9867
# Epoch 17/20
# 19/19 [==============================] - 5s 264ms/step - loss: 0.0141 - accuracy: 0.9954 - val_loss: 0.1193 - val_accuracy: 0.9800
# Epoch 18/20
# 19/19 [==============================] - 5s 262ms/step - loss: 0.0117 - accuracy: 0.9961 - val_loss: 0.1488 - val_accuracy: 0.9867
# Epoch 19/20
# 19/19 [==============================] - 5s 263ms/step - loss: 0.0355 - accuracy: 0.9930 - val_loss: 0.1356 - val_accuracy: 0.9600
# Epoch 20/20
# 19/19 [==============================] - 5s 261ms/step - loss: 0.0252 - accuracy: 0.9944 - val_loss: 0.0379 - val_accuracy: 0.9800
# 5/5 [==============================] - 0s 68ms/step - loss: 0.0379 - accuracy: 0.9800
# Validation Loss = 0.037857841700315475
# Validation Accuracy = 0.9800000190734863

# %%
test_pretrained_layers_freezing_ResNet(20, 5)
# Out:
# Model: "model_60"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_61 (InputLayer)           [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 70, 70, 3)    0           input_61[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 32, 32, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 34, 34, 64)   0           conv1_conv[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 16, 16, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_bn (BatchNo (None, 16, 16, 64)   256         pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_relu (Activ (None, 16, 16, 64)   0           conv2_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 16, 16, 64)   4096        conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 16, 16, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_pad (ZeroPadding (None, 18, 18, 64)   0           conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 16, 16, 64)   36864       conv2_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 16, 16, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 16, 16, 256)  16640       conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 16, 16, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Add)          (None, 16, 16, 256)  0           conv2_block1_0_conv[0][0]
#                                                                  conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_bn (BatchNo (None, 16, 16, 256)  1024        conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_relu (Activ (None, 16, 16, 256)  0           conv2_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 16, 16, 64)   16384       conv2_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 16, 16, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_pad (ZeroPadding (None, 18, 18, 64)   0           conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 16, 16, 64)   36864       conv2_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 16, 16, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 16, 16, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Add)          (None, 16, 16, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_bn (BatchNo (None, 16, 16, 256)  1024        conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_relu (Activ (None, 16, 16, 256)  0           conv2_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 16, 16, 64)   16384       conv2_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 16, 16, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_pad (ZeroPadding (None, 18, 18, 64)   0           conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 8, 8, 64)     36864       conv2_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 8, 8, 64)     0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_64 (MaxPooling2D) (None, 8, 8, 256)    0           conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 8, 8, 256)    16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Add)          (None, 8, 8, 256)    0           max_pooling2d_64[0][0]
#                                                                  conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_bn (BatchNo (None, 8, 8, 256)    1024        conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_relu (Activ (None, 8, 8, 256)    0           conv3_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 8, 8, 128)    32768       conv3_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 8, 8, 128)    0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_pad (ZeroPadding (None, 10, 10, 128)  0           conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 8, 8, 128)    147456      conv3_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 8, 8, 128)    0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 8, 8, 512)    131584      conv3_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 8, 8, 512)    66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Add)          (None, 8, 8, 512)    0           conv3_block1_0_conv[0][0]
#                                                                  conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_bn (BatchNo (None, 8, 8, 512)    2048        conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_relu (Activ (None, 8, 8, 512)    0           conv3_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 8, 8, 128)    65536       conv3_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 8, 8, 128)    0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_pad (ZeroPadding (None, 10, 10, 128)  0           conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 8, 8, 128)    147456      conv3_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 8, 8, 128)    0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 8, 8, 512)    66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Add)          (None, 8, 8, 512)    0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_bn (BatchNo (None, 8, 8, 512)    2048        conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_relu (Activ (None, 8, 8, 512)    0           conv3_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 8, 8, 128)    65536       conv3_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 8, 8, 128)    0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_pad (ZeroPadding (None, 10, 10, 128)  0           conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 8, 8, 128)    147456      conv3_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 8, 8, 128)    0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 8, 8, 512)    66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Add)          (None, 8, 8, 512)    0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_bn (BatchNo (None, 8, 8, 512)    2048        conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_relu (Activ (None, 8, 8, 512)    0           conv3_block4_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 8, 8, 128)    65536       conv3_block4_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 8, 8, 128)    0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_pad (ZeroPadding (None, 10, 10, 128)  0           conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 4, 4, 128)    147456      conv3_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 4, 4, 128)    0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_65 (MaxPooling2D) (None, 4, 4, 512)    0           conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 4, 4, 512)    66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Add)          (None, 4, 4, 512)    0           max_pooling2d_65[0][0]
#                                                                  conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_bn (BatchNo (None, 4, 4, 512)    2048        conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_relu (Activ (None, 4, 4, 512)    0           conv4_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 4, 4, 256)    131072      conv4_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 4, 4, 256)    0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_pad (ZeroPadding (None, 6, 6, 256)    0           conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 4, 4, 256)    589824      conv4_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 4, 4, 256)    0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 4, 4, 1024)   525312      conv4_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 4, 4, 1024)   263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Add)          (None, 4, 4, 1024)   0           conv4_block1_0_conv[0][0]
#                                                                  conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_bn (BatchNo (None, 4, 4, 1024)   4096        conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_relu (Activ (None, 4, 4, 1024)   0           conv4_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 4, 4, 256)    262144      conv4_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 4, 4, 256)    0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_pad (ZeroPadding (None, 6, 6, 256)    0           conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 4, 4, 256)    589824      conv4_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 4, 4, 256)    0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 4, 4, 1024)   263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Add)          (None, 4, 4, 1024)   0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_bn (BatchNo (None, 4, 4, 1024)   4096        conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_relu (Activ (None, 4, 4, 1024)   0           conv4_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 4, 4, 256)    262144      conv4_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 4, 4, 256)    0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_pad (ZeroPadding (None, 6, 6, 256)    0           conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 4, 4, 256)    589824      conv4_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 4, 4, 256)    0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 4, 4, 1024)   263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Add)          (None, 4, 4, 1024)   0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_bn (BatchNo (None, 4, 4, 1024)   4096        conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_relu (Activ (None, 4, 4, 1024)   0           conv4_block4_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 4, 4, 256)    262144      conv4_block4_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 4, 4, 256)    0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_pad (ZeroPadding (None, 6, 6, 256)    0           conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 4, 4, 256)    589824      conv4_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 4, 4, 256)    0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 4, 4, 1024)   263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Add)          (None, 4, 4, 1024)   0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_preact_bn (BatchNo (None, 4, 4, 1024)   4096        conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_preact_relu (Activ (None, 4, 4, 1024)   0           conv4_block5_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 4, 4, 256)    262144      conv4_block5_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 4, 4, 256)    0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_pad (ZeroPadding (None, 6, 6, 256)    0           conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 4, 4, 256)    589824      conv4_block5_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 4, 4, 256)    0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 4, 4, 1024)   263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Add)          (None, 4, 4, 1024)   0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_preact_bn (BatchNo (None, 4, 4, 1024)   4096        conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_preact_relu (Activ (None, 4, 4, 1024)   0           conv4_block6_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 4, 4, 256)    262144      conv4_block6_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 4, 4, 256)    0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_pad (ZeroPadding (None, 6, 6, 256)    0           conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 4, 4, 256)    589824      conv4_block6_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 4, 4, 256)    0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 4, 4, 1024)   263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Add)          (None, 4, 4, 1024)   0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_preact_bn (BatchNo (None, 4, 4, 1024)   4096        conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv4_block7_preact_relu (Activ (None, 4, 4, 1024)   0           conv4_block7_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 4, 4, 256)    262144      conv4_block7_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (Activation (None, 4, 4, 256)    0           conv4_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_pad (ZeroPadding (None, 6, 6, 256)    0           conv4_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, 4, 4, 256)    589824      conv4_block7_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_relu (Activation (None, 4, 4, 256)    0           conv4_block7_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_3_conv (Conv2D)    (None, 4, 4, 1024)   263168      conv4_block7_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_out (Add)          (None, 4, 4, 1024)   0           conv4_block6_out[0][0]
#                                                                  conv4_block7_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_preact_bn (BatchNo (None, 4, 4, 1024)   4096        conv4_block7_out[0][0]
# __________________________________________________________________________________________________
# conv4_block8_preact_relu (Activ (None, 4, 4, 1024)   0           conv4_block8_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_conv (Conv2D)    (None, 4, 4, 256)    262144      conv4_block8_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_relu (Activation (None, 4, 4, 256)    0           conv4_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_pad (ZeroPadding (None, 6, 6, 256)    0           conv4_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, 4, 4, 256)    589824      conv4_block8_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_relu (Activation (None, 4, 4, 256)    0           conv4_block8_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_3_conv (Conv2D)    (None, 4, 4, 1024)   263168      conv4_block8_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_out (Add)          (None, 4, 4, 1024)   0           conv4_block7_out[0][0]
#                                                                  conv4_block8_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_preact_bn (BatchNo (None, 4, 4, 1024)   4096        conv4_block8_out[0][0]
# __________________________________________________________________________________________________
# conv4_block9_preact_relu (Activ (None, 4, 4, 1024)   0           conv4_block9_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_conv (Conv2D)    (None, 4, 4, 256)    262144      conv4_block9_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_relu (Activation (None, 4, 4, 256)    0           conv4_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_pad (ZeroPadding (None, 6, 6, 256)    0           conv4_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_conv (Conv2D)    (None, 4, 4, 256)    589824      conv4_block9_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_relu (Activation (None, 4, 4, 256)    0           conv4_block9_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_3_conv (Conv2D)    (None, 4, 4, 1024)   263168      conv4_block9_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_out (Add)          (None, 4, 4, 1024)   0           conv4_block8_out[0][0]
#                                                                  conv4_block9_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_preact_bn (BatchN (None, 4, 4, 1024)   4096        conv4_block9_out[0][0]
# __________________________________________________________________________________________________
# conv4_block10_preact_relu (Acti (None, 4, 4, 1024)   0           conv4_block10_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_conv (Conv2D)   (None, 4, 4, 256)    262144      conv4_block10_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_relu (Activatio (None, 4, 4, 256)    0           conv4_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_pad (ZeroPaddin (None, 6, 6, 256)    0           conv4_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_conv (Conv2D)   (None, 4, 4, 256)    589824      conv4_block10_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_relu (Activatio (None, 4, 4, 256)    0           conv4_block10_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      conv4_block10_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_out (Add)         (None, 4, 4, 1024)   0           conv4_block9_out[0][0]
#                                                                  conv4_block10_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_preact_bn (BatchN (None, 4, 4, 1024)   4096        conv4_block10_out[0][0]
# __________________________________________________________________________________________________
# conv4_block11_preact_relu (Acti (None, 4, 4, 1024)   0           conv4_block11_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_conv (Conv2D)   (None, 4, 4, 256)    262144      conv4_block11_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_relu (Activatio (None, 4, 4, 256)    0           conv4_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_pad (ZeroPaddin (None, 6, 6, 256)    0           conv4_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_conv (Conv2D)   (None, 4, 4, 256)    589824      conv4_block11_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_relu (Activatio (None, 4, 4, 256)    0           conv4_block11_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      conv4_block11_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_out (Add)         (None, 4, 4, 1024)   0           conv4_block10_out[0][0]
#                                                                  conv4_block11_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_preact_bn (BatchN (None, 4, 4, 1024)   4096        conv4_block11_out[0][0]
# __________________________________________________________________________________________________
# conv4_block12_preact_relu (Acti (None, 4, 4, 1024)   0           conv4_block12_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_conv (Conv2D)   (None, 4, 4, 256)    262144      conv4_block12_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_relu (Activatio (None, 4, 4, 256)    0           conv4_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_pad (ZeroPaddin (None, 6, 6, 256)    0           conv4_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_conv (Conv2D)   (None, 4, 4, 256)    589824      conv4_block12_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_relu (Activatio (None, 4, 4, 256)    0           conv4_block12_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      conv4_block12_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_out (Add)         (None, 4, 4, 1024)   0           conv4_block11_out[0][0]
#                                                                  conv4_block12_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_preact_bn (BatchN (None, 4, 4, 1024)   4096        conv4_block12_out[0][0]
# __________________________________________________________________________________________________
# conv4_block13_preact_relu (Acti (None, 4, 4, 1024)   0           conv4_block13_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block13_1_conv (Conv2D)   (None, 4, 4, 256)    262144      conv4_block13_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block13_1_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block13_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_1_relu (Activatio (None, 4, 4, 256)    0           conv4_block13_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_pad (ZeroPaddin (None, 6, 6, 256)    0           conv4_block13_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_conv (Conv2D)   (None, 4, 4, 256)    589824      conv4_block13_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block13_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_relu (Activatio (None, 4, 4, 256)    0           conv4_block13_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block13_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      conv4_block13_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block13_out (Add)         (None, 4, 4, 1024)   0           conv4_block12_out[0][0]
#                                                                  conv4_block13_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block14_preact_bn (BatchN (None, 4, 4, 1024)   4096        conv4_block13_out[0][0]
# ...
# conv4_block22_preact_bn (BatchN (None, 4, 4, 1024)   4096        conv4_block21_out[0][0]
# __________________________________________________________________________________________________
# conv4_block22_preact_relu (Acti (None, 4, 4, 1024)   0           conv4_block22_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block22_1_conv (Conv2D)   (None, 4, 4, 256)    262144      conv4_block22_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block22_1_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block22_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block22_1_relu (Activatio (None, 4, 4, 256)    0           conv4_block22_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block22_2_pad (ZeroPaddin (None, 6, 6, 256)    0           conv4_block22_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block22_2_conv (Conv2D)   (None, 4, 4, 256)    589824      conv4_block22_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block22_2_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block22_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block22_2_relu (Activatio (None, 4, 4, 256)    0           conv4_block22_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block22_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      conv4_block22_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block22_out (Add)         (None, 4, 4, 1024)   0           conv4_block21_out[0][0]
#                                                                  conv4_block22_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block23_preact_bn (BatchN (None, 4, 4, 1024)   4096        conv4_block22_out[0][0]
# __________________________________________________________________________________________________
# conv4_block23_preact_relu (Acti (None, 4, 4, 1024)   0           conv4_block23_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block23_1_conv (Conv2D)   (None, 4, 4, 256)    262144      conv4_block23_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block23_1_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block23_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block23_1_relu (Activatio (None, 4, 4, 256)    0           conv4_block23_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block23_2_pad (ZeroPaddin (None, 6, 6, 256)    0           conv4_block23_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block23_2_conv (Conv2D)   (None, 2, 2, 256)    589824      conv4_block23_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block23_2_bn (BatchNormal (None, 2, 2, 256)    1024        conv4_block23_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block23_2_relu (Activatio (None, 2, 2, 256)    0           conv4_block23_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_66 (MaxPooling2D) (None, 2, 2, 1024)   0           conv4_block22_out[0][0]
# __________________________________________________________________________________________________
# conv4_block23_3_conv (Conv2D)   (None, 2, 2, 1024)   263168      conv4_block23_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block23_out (Add)         (None, 2, 2, 1024)   0           max_pooling2d_66[0][0]
#                                                                  conv4_block23_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_preact_bn (BatchNo (None, 2, 2, 1024)   4096        conv4_block23_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_preact_relu (Activ (None, 2, 2, 1024)   0           conv5_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 2, 2, 512)    524288      conv5_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 2, 2, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_pad (ZeroPadding (None, 4, 4, 512)    0           conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 2, 2, 512)    2359296     conv5_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 2, 2, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 2, 2, 2048)   2099200     conv5_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 2, 2, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Add)          (None, 2, 2, 2048)   0           conv5_block1_0_conv[0][0]
#                                                                  conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_preact_bn (BatchNo (None, 2, 2, 2048)   8192        conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_preact_relu (Activ (None, 2, 2, 2048)   0           conv5_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 2, 2, 512)    1048576     conv5_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 2, 2, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_pad (ZeroPadding (None, 4, 4, 512)    0           conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 2, 2, 512)    2359296     conv5_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 2, 2, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 2, 2, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Add)          (None, 2, 2, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_bn (BatchNo (None, 2, 2, 2048)   8192        conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_relu (Activ (None, 2, 2, 2048)   0           conv5_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 2, 2, 512)    1048576     conv5_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 2, 2, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_pad (ZeroPadding (None, 4, 4, 512)    0           conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 2, 2, 512)    2359296     conv5_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 2, 2, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 2, 2, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Add)          (None, 2, 2, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# post_bn (BatchNormalization)    (None, 2, 2, 2048)   8192        conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# post_relu (Activation)          (None, 2, 2, 2048)   0           post_bn[0][0]
# __________________________________________________________________________________________________
# flatten_60 (Flatten)            (None, 8192)         0           post_relu[0][0]
# __________________________________________________________________________________________________
# dense_60 (Dense)                (None, 256)          2097408     flatten_60[0][0]
# __________________________________________________________________________________________________
# fc (Dense)                      (None, 1)            257         dense_60[0][0]
# ==================================================================================================
# Total params: 44,724,225
# Trainable params: 44,617,089
# Non-trainable params: 107,136
# __________________________________________________________________________________________________
# Epoch 1/20
# 19/19 [==============================] - 19s 367ms/step - loss: 0.6067 - accuracy: 0.6561 - val_loss: 0.6881 - val_accuracy: 0.6600
# Epoch 2/20
# 19/19 [==============================] - 5s 261ms/step - loss: 0.1716 - accuracy: 0.9400 - val_loss: 0.8130 - val_accuracy: 0.7267
# Epoch 3/20
# 19/19 [==============================] - 5s 261ms/step - loss: 0.1166 - accuracy: 0.9646 - val_loss: 0.5308 - val_accuracy: 0.7400
# Epoch 4/20
# 19/19 [==============================] - 5s 261ms/step - loss: 0.0717 - accuracy: 0.9760 - val_loss: 0.3528 - val_accuracy: 0.8333
# Epoch 5/20
# 19/19 [==============================] - 5s 262ms/step - loss: 0.0709 - accuracy: 0.9844 - val_loss: 0.2732 - val_accuracy: 0.8733
# Epoch 6/20
# 19/19 [==============================] - 5s 262ms/step - loss: 0.0514 - accuracy: 0.9855 - val_loss: 0.1531 - val_accuracy: 0.9467
# Epoch 7/20
# 19/19 [==============================] - 5s 261ms/step - loss: 0.0363 - accuracy: 0.9851 - val_loss: 0.1986 - val_accuracy: 0.9533
# Epoch 8/20
# 19/19 [==============================] - 5s 261ms/step - loss: 0.0688 - accuracy: 0.9843 - val_loss: 0.1605 - val_accuracy: 0.9667
# Epoch 9/20
# 19/19 [==============================] - 5s 261ms/step - loss: 0.0224 - accuracy: 0.9936 - val_loss: 0.1653 - val_accuracy: 0.9733
# Epoch 10/20
# 19/19 [==============================] - 5s 262ms/step - loss: 0.0122 - accuracy: 0.9990 - val_loss: 0.1607 - val_accuracy: 0.9667
# Epoch 11/20
# 19/19 [==============================] - 5s 260ms/step - loss: 0.0355 - accuracy: 0.9907 - val_loss: 0.2692 - val_accuracy: 0.9533
# Epoch 12/20
# 19/19 [==============================] - 5s 262ms/step - loss: 0.0472 - accuracy: 0.9868 - val_loss: 0.1744 - val_accuracy: 0.9733
# Epoch 13/20
# 19/19 [==============================] - 5s 262ms/step - loss: 0.0084 - accuracy: 0.9986 - val_loss: 0.1746 - val_accuracy: 0.9800
# Epoch 14/20
# 19/19 [==============================] - 5s 261ms/step - loss: 0.0070 - accuracy: 0.9969 - val_loss: 0.1210 - val_accuracy: 0.9867
# Epoch 15/20
# 19/19 [==============================] - 5s 261ms/step - loss: 0.0050 - accuracy: 0.9970 - val_loss: 0.1710 - val_accuracy: 0.9733
# Epoch 16/20
# 19/19 [==============================] - 5s 261ms/step - loss: 0.0111 - accuracy: 0.9974 - val_loss: 0.3497 - val_accuracy: 0.9333
# Epoch 17/20
# 19/19 [==============================] - 5s 261ms/step - loss: 0.0162 - accuracy: 0.9937 - val_loss: 0.1492 - val_accuracy: 0.9800
# Epoch 18/20
# 19/19 [==============================] - 5s 263ms/step - loss: 0.0336 - accuracy: 0.9930 - val_loss: 0.0558 - val_accuracy: 0.9800
# Epoch 19/20
# 19/19 [==============================] - 5s 262ms/step - loss: 0.0134 - accuracy: 0.9964 - val_loss: 0.2070 - val_accuracy: 0.9667
# Epoch 20/20
# 19/19 [==============================] - 5s 262ms/step - loss: 0.0212 - accuracy: 0.9963 - val_loss: 0.1319 - val_accuracy: 0.9800
# 5/5 [==============================] - 0s 70ms/step - loss: 0.1319 - accuracy: 0.9800
# Validation Loss = 0.13185107707977295
# Validation Accuracy = 0.9800000190734863

# %%
test_untrained_MobileNet(100)
# Out:
# Model: "model_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_16 (InputLayer)        [(None, 64, 64, 3)]       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 32, 32, 32)        864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 32, 32, 32)        128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 32, 32, 32)        0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 32, 32, 32)        288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 32, 32, 32)        128
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, 32, 32, 32)        0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 32, 32, 64)        2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 32, 32, 64)        256
# _________________________________________________________________
# conv_pw_1_relu (ReLU)        (None, 32, 32, 64)        0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, 33, 33, 64)        0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 16, 16, 64)        576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 16, 16, 64)        256
# _________________________________________________________________
# conv_dw_2_relu (ReLU)        (None, 16, 16, 64)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 16, 16, 128)       8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 16, 16, 128)       512
# _________________________________________________________________
# conv_pw_2_relu (ReLU)        (None, 16, 16, 128)       0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 16, 16, 128)       1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 16, 16, 128)       512
# _________________________________________________________________
# conv_dw_3_relu (ReLU)        (None, 16, 16, 128)       0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 16, 16, 128)       16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 16, 16, 128)       512
# _________________________________________________________________
# conv_pw_3_relu (ReLU)        (None, 16, 16, 128)       0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, 17, 17, 128)       0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 8, 8, 128)         1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 8, 8, 128)         512
# _________________________________________________________________
# conv_dw_4_relu (ReLU)        (None, 8, 8, 128)         0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 8, 8, 256)         32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv_pw_4_relu (ReLU)        (None, 8, 8, 256)         0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 8, 8, 256)         2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv_dw_5_relu (ReLU)        (None, 8, 8, 256)         0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 8, 8, 256)         65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv_pw_5_relu (ReLU)        (None, 8, 8, 256)         0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, 9, 9, 256)         0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 4, 4, 256)         2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 4, 4, 256)         1024
# _________________________________________________________________
# conv_dw_6_relu (ReLU)        (None, 4, 4, 256)         0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 4, 4, 512)         131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_pw_6_relu (ReLU)        (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 4, 4, 512)         4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_dw_7_relu (ReLU)        (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 4, 4, 512)         262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_pw_7_relu (ReLU)        (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 4, 4, 512)         4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_dw_8_relu (ReLU)        (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 4, 4, 512)         262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_pw_8_relu (ReLU)        (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 4, 4, 512)         4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_dw_9_relu (ReLU)        (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 4, 4, 512)         262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_pw_9_relu (ReLU)        (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 4, 4, 512)         4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_dw_10_relu (ReLU)       (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 4, 4, 512)         262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_pw_10_relu (ReLU)       (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 4, 4, 512)         4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_dw_11_relu (ReLU)       (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 4, 4, 512)         262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_pw_11_relu (ReLU)       (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, 5, 5, 512)         0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, 2, 2, 512)         4608
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, 2, 2, 512)         2048
# _________________________________________________________________
# conv_dw_12_relu (ReLU)       (None, 2, 2, 512)         0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, 2, 2, 1024)        524288
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, 2, 2, 1024)        4096
# _________________________________________________________________
# conv_pw_12_relu (ReLU)       (None, 2, 2, 1024)        0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, 2, 2, 1024)        9216
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, 2, 2, 1024)        4096
# _________________________________________________________________
# conv_dw_13_relu (ReLU)       (None, 2, 2, 1024)        0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, 2, 2, 1024)        1048576
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, 2, 2, 1024)        4096
# _________________________________________________________________
# conv_pw_13_relu (ReLU)       (None, 2, 2, 1024)        0
# _________________________________________________________________
# flatten_15 (Flatten)         (None, 4096)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 256)               1048832
# _________________________________________________________________
# fc (Dense)                   (None, 1)                 257
# =================================================================
# Total params: 4,277,953
# Trainable params: 4,256,065
# Non-trainable params: 21,888
# _________________________________________________________________
# Epoch 1/100
# 19/19 [==============================] - 5s 56ms/step - loss: 0.9910 - accuracy: 0.4617 - val_loss: 0.8895 - val_accuracy: 0.4400
# Epoch 2/100
# 19/19 [==============================] - 1s 28ms/step - loss: 0.7974 - accuracy: 0.6355 - val_loss: 0.8922 - val_accuracy: 0.4400
# Epoch 3/100
# 19/19 [==============================] - 1s 31ms/step - loss: 0
100
# 19/19 [==============================] - 1s 29ms/step - loss: 0.5089 - accuracy: 0.9997 - val_loss: 1.8401 - val_accuracy: 0.8333
# Epoch 96/100
# 19/19 [==============================] - 1s 27ms/step - loss: 0.4860 - accuracy: 0.9991 - val_loss: 1.6840 - val_accuracy: 0.8600
# Epoch 97/100
# 19/19 [==============================] - 1s 28ms/step - loss: 0.5050 - accuracy: 0.9997 - val_loss: 1.4079 - val_accuracy: 0.8467
# Epoch 98/100
# 19/19 [==============================] - 1s 29ms/step - loss: 0.5268 - accuracy: 0.9973 - val_loss: 1.3657 - val_accuracy: 0.8533
# Epoch 99/100
# 19/19 [==============================] - 1s 29ms/step - loss: 0.4990 - accuracy: 0.9899 - val_loss: 1.9157 - val_accuracy: 0.8400
# Epoch 100/100
# 19/19 [==============================] - 1s 29ms/step - loss: 0.4911 - accuracy: 1.0000 - val_loss: 1.6967 - val_accuracy: 0.8533
# 5/5 [==============================] - 0s 7ms/step - loss: 1.6967 - accuracy: 0.8533
# Validation Loss = 1.6967145204544067
# Validation Accuracy = 0.8533333539962769

# %%
test_pretrained_MobileNet(20)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "model_59"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_60 (InputLayer)        [(None, 64, 64, 3)]       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 32, 32, 32)        864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 32, 32, 32)        128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 32, 32, 32)        0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 32, 32, 32)        288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 32, 32, 32)        128
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, 32, 32, 32)        0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 32, 32, 64)        2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 32, 32, 64)        256
# _________________________________________________________________
# conv_pw_1_relu (ReLU)        (None, 32, 32, 64)        0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, 33, 33, 64)        0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 16, 16, 64)        576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 16, 16, 64)        256
# _________________________________________________________________
# conv_dw_2_relu (ReLU)        (None, 16, 16, 64)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 16, 16, 128)       8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 16, 16, 128)       512
# _________________________________________________________________
# conv_pw_2_relu (ReLU)        (None, 16, 16, 128)       0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 16, 16, 128)       1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 16, 16, 128)       512
# _________________________________________________________________
# conv_dw_3_relu (ReLU)        (None, 16, 16, 128)       0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 16, 16, 128)       16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 16, 16, 128)       512
# _________________________________________________________________
# conv_pw_3_relu (ReLU)        (None, 16, 16, 128)       0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, 17, 17, 128)       0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 8, 8, 128)         1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 8, 8, 128)         512
# _________________________________________________________________
# conv_dw_4_relu (ReLU)        (None, 8, 8, 128)         0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 8, 8, 256)         32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv_pw_4_relu (ReLU)        (None, 8, 8, 256)         0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 8, 8, 256)         2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv_dw_5_relu (ReLU)        (None, 8, 8, 256)         0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 8, 8, 256)         65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv_pw_5_relu (ReLU)        (None, 8, 8, 256)         0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, 9, 9, 256)         0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 4, 4, 256)         2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 4, 4, 256)         1024
# _________________________________________________________________
# conv_dw_6_relu (ReLU)        (None, 4, 4, 256)         0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 4, 4, 512)         131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_pw_6_relu (ReLU)        (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 4, 4, 512)         4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_dw_7_relu (ReLU)        (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 4, 4, 512)         262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_pw_7_relu (ReLU)        (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 4, 4, 512)         4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_dw_8_relu (ReLU)        (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 4, 4, 512)         262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_pw_8_relu (ReLU)        (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 4, 4, 512)         4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_dw_9_relu (ReLU)        (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 4, 4, 512)         262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_pw_9_relu (ReLU)        (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 4, 4, 512)         4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_dw_10_relu (ReLU)       (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 4, 4, 512)         262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_pw_10_relu (ReLU)       (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 4, 4, 512)         4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_dw_11_relu (ReLU)       (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 4, 4, 512)         262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_pw_11_relu (ReLU)       (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, 5, 5, 512)         0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, 2, 2, 512)         4608
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, 2, 2, 512)         2048
# _________________________________________________________________
# conv_dw_12_relu (ReLU)       (None, 2, 2, 512)         0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, 2, 2, 1024)        524288
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, 2, 2, 1024)        4096
# _________________________________________________________________
# conv_pw_12_relu (ReLU)       (None, 2, 2, 1024)        0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, 2, 2, 1024)        9216
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, 2, 2, 1024)        4096
# _________________________________________________________________
# conv_dw_13_relu (ReLU)       (None, 2, 2, 1024)        0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, 2, 2, 1024)        1048576
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, 2, 2, 1024)        4096
# _________________________________________________________________
# conv_pw_13_relu (ReLU)       (None, 2, 2, 1024)        0
# _________________________________________________________________
# flatten_59 (Flatten)         (None, 4096)              0
# _________________________________________________________________
# dense_59 (Dense)             (None, 256)               1048832
# _________________________________________________________________
# fc (Dense)                   (None, 1)                 257
# =================================================================
# Total params: 4,277,953
# Trainable params: 4,256,065
# Non-trainable params: 21,888
# _________________________________________________________________
# Epoch 1/20
# 19/19 [==============================] - 4s 76ms/step - loss: 8.6839 - accuracy: 0.5891 - val_loss: 12.4641 - val_accuracy: 0.4400
# Epoch 2/20
# 19/19 [==============================] - 1s 41ms/step - loss: 0.6515 - accuracy: 0.7871 - val_loss: 11.7366 - val_accuracy: 0.4400
# Epoch 3/20
# 19/19 [==============================] - 1s 42ms/step - loss: 0.1576 - accuracy: 0.9448 - val_loss: 14.5579 - val_accuracy: 0.4400
# Epoch 4/20
# 19/19 [==============================] - 1s 41ms/step - loss: 0.1472 - accuracy: 0.9600 - val_loss: 8.6189 - val_accuracy: 0.4400
# Epoch 5/20
# 19/19 [==============================] - 1s 41ms/step - loss: 0.1418 - accuracy: 0.9587 - val_loss: 14.3605 - val_accuracy: 0.4400
# Epoch 6/20
# 19/19 [==============================] - 1s 42ms/step - loss: 0.1342 - accuracy: 0.9580 - val_loss: 1.7059 - val_accuracy: 0.6867
# Epoch 7/20
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0860 - accuracy: 0.9798 - val_loss: 2.3422 - val_accuracy: 0.6800
# Epoch 8/20
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0657 - accuracy: 0.9738 - val_loss: 1.6251 - val_accuracy: 0.6867
# Epoch 9/20
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0440 - accuracy: 0.9804 - val_loss: 1.5290 - val_accuracy: 0.8067
# Epoch 10/20
# 19/19 [==============================] - 1s 41ms/step - loss: 0.0465 - accuracy: 0.9932 - val_loss: 2.6678 - val_accuracy: 0.7400
# Epoch 11/20
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0429 - accuracy: 0.9817 - val_loss: 2.8221 - val_accuracy: 0.7400
# Epoch 12/20
# 19/19 [==============================] - 1s 42ms/step - loss: 0.1164 - accuracy: 0.9578 - val_loss: 2.8274 - val_accuracy: 0.7200
# Epoch 13/20
# 19/19 [==============================] - 1s 41ms/step - loss: 0.0478 - accuracy: 0.9816 - val_loss: 2.6687 - val_accuracy: 0.7333
# Epoch 14/20
# 19/19 [==============================] - 1s 41ms/step - loss: 0.0271 - accuracy: 0.9877 - val_loss: 0.4104 - val_accuracy: 0.9333
# Epoch 15/20
# 19/19 [==============================] - 1s 41ms/step - loss: 0.0088 - accuracy: 0.9992 - val_loss: 0.1220 - val_accuracy: 0.9867
# Epoch 16/20
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0039 - accuracy: 0.9996 - val_loss: 0.4154 - val_accuracy: 0.9267
# Epoch 17/20
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0094 - accuracy: 0.9948 - val_loss: 0.5527 - val_accuracy: 0.9467
# Epoch 18/20
# 19/19 [==============================] - 1s 41ms/step - loss: 0.0552 - accuracy: 0.9833 - val_loss: 0.4231 - val_accuracy: 0.8867
# Epoch 19/20
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0319 - accuracy: 0.9911 - val_loss: 0.2308 - val_accuracy: 0.9467
# Epoch 20/20
# 19/19 [==============================] - 1s 41ms/step - loss: 0.0120 - accuracy: 0.9986 - val_loss: 0.1250 - val_accuracy: 0.9667
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1250 - accuracy: 0.9667
# Validation Loss = 0.12504178285598755
# Validation Accuracy = 0.9666666388511658

# %%
test_pretrained_layers_freezing_MobileNet(20, 15)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "model_52"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_53 (InputLayer)        [(None, 64, 64, 3)]       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 32, 32, 32)        864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 32, 32, 32)        128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 32, 32, 32)        0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 32, 32, 32)        288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 32, 32, 32)        128
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, 32, 32, 32)        0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 32, 32, 64)        2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 32, 32, 64)        256
# _________________________________________________________________
# conv_pw_1_relu (ReLU)        (None, 32, 32, 64)        0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, 33, 33, 64)        0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 16, 16, 64)        576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 16, 16, 64)        256
# _________________________________________________________________
# conv_dw_2_relu (ReLU)        (None, 16, 16, 64)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 16, 16, 128)       8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 16, 16, 128)       512
# _________________________________________________________________
# conv_pw_2_relu (ReLU)        (None, 16, 16, 128)       0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 16, 16, 128)       1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 16, 16, 128)       512
# _________________________________________________________________
# conv_dw_3_relu (ReLU)        (None, 16, 16, 128)       0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 16, 16, 128)       16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 16, 16, 128)       512
# _________________________________________________________________
# conv_pw_3_relu (ReLU)        (None, 16, 16, 128)       0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, 17, 17, 128)       0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 8, 8, 128)         1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 8, 8, 128)         512
# _________________________________________________________________
# conv_dw_4_relu (ReLU)        (None, 8, 8, 128)         0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 8, 8, 256)         32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv_pw_4_relu (ReLU)        (None, 8, 8, 256)         0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 8, 8, 256)         2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv_dw_5_relu (ReLU)        (None, 8, 8, 256)         0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 8, 8, 256)         65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv_pw_5_relu (ReLU)        (None, 8, 8, 256)         0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, 9, 9, 256)         0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 4, 4, 256)         2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 4, 4, 256)         1024
# _________________________________________________________________
# conv_dw_6_relu (ReLU)        (None, 4, 4, 256)         0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 4, 4, 512)         131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_pw_6_relu (ReLU)        (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 4, 4, 512)         4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_dw_7_relu (ReLU)        (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 4, 4, 512)         262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_pw_7_relu (ReLU)        (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 4, 4, 512)         4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_dw_8_relu (ReLU)        (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 4, 4, 512)         262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_pw_8_relu (ReLU)        (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 4, 4, 512)         4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_dw_9_relu (ReLU)        (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 4, 4, 512)         262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_pw_9_relu (ReLU)        (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 4, 4, 512)         4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_dw_10_relu (ReLU)       (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 4, 4, 512)         262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_pw_10_relu (ReLU)       (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 4, 4, 512)         4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_dw_11_relu (ReLU)       (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 4, 4, 512)         262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_pw_11_relu (ReLU)       (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, 5, 5, 512)         0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, 2, 2, 512)         4608
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, 2, 2, 512)         2048
# _________________________________________________________________
# conv_dw_12_relu (ReLU)       (None, 2, 2, 512)         0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, 2, 2, 1024)        524288
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, 2, 2, 1024)        4096
# _________________________________________________________________
# conv_pw_12_relu (ReLU)       (None, 2, 2, 1024)        0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, 2, 2, 1024)        9216
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, 2, 2, 1024)        4096
# _________________________________________________________________
# conv_dw_13_relu (ReLU)       (None, 2, 2, 1024)        0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, 2, 2, 1024)        1048576
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, 2, 2, 1024)        4096
# _________________________________________________________________
# conv_pw_13_relu (ReLU)       (None, 2, 2, 1024)        0
# _________________________________________________________________
# flatten_52 (Flatten)         (None, 4096)              0
# _________________________________________________________________
# dense_52 (Dense)             (None, 256)               1048832
# _________________________________________________________________
# fc (Dense)                   (None, 1)                 257
# =================================================================
# Total params: 4,277,953
# Trainable params: 4,243,713
# Non-trainable params: 34,240
# _________________________________________________________________
# Epoch 1/20
# 19/19 [==============================] - 4s 74ms/step - loss: 0.9284 - accuracy: 0.6760 - val_loss: 1.4781 - val_accuracy: 0.4467
# Epoch 2/20
# 19/19 [==============================] - 1s 37ms/step - loss: 0.5290 - accuracy: 0.9650 - val_loss: 1.3197 - val_accuracy: 0.4667
# Epoch 3/20
# 19/19 [==============================] - 1s 36ms/step - loss: 0.4871 - accuracy: 0.9881 - val_loss: 1.0218 - val_accuracy: 0.5600
# Epoch 4/20
# 19/19 [==============================] - 1s 36ms/step - loss: 0.5382 - accuracy: 0.9989 - val_loss: 1.0862 - val_accuracy: 0.5933
# Epoch 5/20
# 19/19 [==============================] - 1s 35ms/step - loss: 0.5332 - accuracy: 0.9892 - val_loss: 0.8486 - val_accuracy: 0.7600
# Epoch 6/20
# 19/19 [==============================] - 1s 36ms/step - loss: 0.4993 - accuracy: 0.9978 - val_loss: 0.9099 - val_accuracy: 0.7533
# Epoch 7/20
# 19/19 [==============================] - 1s 36ms/step - loss: 0.5272 - accuracy: 0.9899 - val_loss: 0.7602 - val_accuracy: 0.8533
# Epoch 8/20
# 19/19 [==============================] - 1s 36ms/step - loss: 0.5477 - accuracy: 0.9858 - val_loss: 0.7163 - val_accuracy: 0.8867
# Epoch 9/20
# 19/19 [==============================] - 1s 36ms/step - loss: 0.4810 - accuracy: 0.9859 - val_loss: 0.6717 - val_accuracy: 0.9067
# Epoch 10/20
# 19/19 [==============================] - 1s 36ms/step - loss: 0.5059 - accuracy: 0.9970 - val_loss: 0.6721 - val_accuracy: 0.9133
# Epoch 11/20
# 19/19 [==============================] - 1s 35ms/step - loss: 0.5017 - accuracy: 0.9958 - val_loss: 0.6210 - val_accuracy: 0.9467
# Epoch 12/20
# 19/19 [==============================] - 1s 35ms/step - loss: 0.4923 - accuracy: 0.9855 - val_loss: 0.6022 - val_accuracy: 0.9667
# Epoch 13/20
# 19/19 [==============================] - 1s 36ms/step - loss: 0.5444 - accuracy: 0.9856 - val_loss: 0.7130 - val_accuracy: 0.9333
# Epoch 14/20
# 19/19 [==============================] - 1s 35ms/step - loss: 0.5195 - accuracy: 0.9914 - val_loss: 0.6627 - val_accuracy: 0.9467
# Epoch 15/20
# 19/19 [==============================] - 1s 36ms/step - loss: 0.4755 - accuracy: 0.9944 - val_loss: 0.5917 - val_accuracy: 0.9600
# Epoch 16/20
# 19/19 [==============================] - 1s 35ms/step - loss: 0.4974 - accuracy: 0.9945 - val_loss: 0.6029 - val_accuracy: 0.9733
# Epoch 17/20
# 19/19 [==============================] - 1s 35ms/step - loss: 0.5020 - accuracy: 0.9979 - val_loss: 0.5946 - val_accuracy: 0.9667
# Epoch 18/20
# 19/19 [==============================] - 1s 35ms/step - loss: 0.5241 - accuracy: 0.9923 - val_loss: 0.5953 - val_accuracy: 0.9667
# Epoch 19/20
# 19/19 [==============================] - 1s 36ms/step - loss: 0.4903 - accuracy: 0.9947 - val_loss: 0.6249 - val_accuracy: 0.9667
# Epoch 20/20
# 19/19 [==============================] - 1s 36ms/step - loss: 0.5104 - accuracy: 0.9811 - val_loss: 0.5847 - val_accuracy: 0.9733
# 5/5 [==============================] - 0s 12ms/step - loss: 0.5847 - accuracy: 0.9733
# Validation Loss = 0.5846526026725769
# Validation Accuracy = 0.9733333587646484

# %% [markdown]
# ## 3.3 Conclusion

# %% [markdown]
# That's it! Congratulations on training CNN use cases models.
#
# Make sure you deliver all the requirements for the submission.
