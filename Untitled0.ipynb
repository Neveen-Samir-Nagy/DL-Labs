# %% [markdown]
# <table align="center">
#   <td align="center"><a target="_blank" href="https://colab.research.google.com/github/KhaledElTahan/DeepLearning/blob/master/Labs/lab2/lab2.ipynb">
#         <img src="http://introtodeeplearning.com/images/colab/colab.png?v2.0"  style="padding-bottom:5px;" />Run in Google Colab</a></td>
# </table>

# %% [markdown]
# # Lab 2: Multinominal Classification

# %% [markdown]
# ![Multinominal Classification Network](https://github.com/KhaledElTahan/DeepLearning/blob/master/Labs/lab2/multinominal_classification_net.png?raw=1)

# %% [markdown]
# ## 2.1 Problem Statement

# %% [markdown]
# In this lab we will be addressing the task of multinominal classification of handwritten digits from the famous MNIST dataset.
#
# The MNIST dataset consists of 60,000 training images and 10,000 test images.  Our classes are the digits 0-9.
#
# You are required to build 2 models to solve this problem:
# 1. A simple using fully connected layers.
# 2. A model using Convolutional Neural Network (CNN) before applying the simple model.
#
# You should perform different experiments on the two models, observe the difference in **accuracy** and report them.

# %% [markdown]
# ## 2.2 Problem Details

# %% [markdown]
# ### 2.2.1 Dataset Loading

# %% [markdown]
# #### Import Needed packages

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import random
from progressbar import progressbar
from keras.utils import to_categorical

# %% [markdown]
# #### Load Dataset

# %%
mnist = tf.keras.datasets.mnist
(train_images, train_labels), (val_images, val_labels) = mnist.load_data()

train_images = np.expand_dims(train_images, axis=-1) / 255.
train_labels = np.int64(train_labels)

val_images = np.expand_dims(val_images, axis=-1) / 255.
val_labels = np.int64(val_labels)

# %%
y_train = to_categorical(train_labels, 10)
y_val = to_categorical(val_labels, 10)
print(train_images.shape, y_train.shape)
print(val_images.shape, y_val.shape)
# Out:
# (60000, 28, 28, 1) (60000, 10)
# (10000, 28, 28, 1) (10000, 10)

# %% [markdown]
# #### Plot Dataset Sample

# %%
plt.figure(figsize=(10, 10))
random_inds = np.random.choice(60000, 36)
for i in range(36):
    plt.subplot(6, 6, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    image_ind = random_inds[i]
    plt.imshow(np.squeeze(train_images[image_ind]), cmap=plt.cm.binary)
    plt.xlabel(train_labels[image_ind])

# %% [markdown]
# ### 2.2.1 Fully Connected Neural Network Solution

# %% [markdown]
# Build a neural network, using tf.keras, consisting of 2 fully connected layers and apply this to the digit classification task, Our network will ultimately output a probability distribution over the 10 digit classes (0-9).

# %% [markdown]
# ![Two Layer Neural Network](https://github.com/KhaledElTahan/DeepLearning/blob/master/Labs/lab2/2layer_nn.png?raw=1)

# %% [markdown]
# #### Define the Two-Layer Neural Network

# %% [markdown]
# **TODO**
#
# 1. Define two layer neural network exactly as in the previous figure by adding two [dense layers](https://keras.io/api/layers/core_layers/dense/).
# 2. Try different [activation functions](https://keras.io/api/layers/#layer-activations) for both layers (ReLU, Tanh, and other activations for first layer - Softmax, and other activations for output layer), and report the difference in **accuracy** and plots.
# 3. Try different [regularization kernerls](https://keras.io/api/layers/#layer-weight-regularizers), and [regularization layers](https://keras.io/api/layers/#regularization-layers) (L1, L2, Dropout, and other regularizations), and report the difference in **accuracy** and plots.

# %%
act = ['relu','softmax','tanh','sigmoid']
opt = [tf.keras.optimizers.SGD(), tf.keras.optimizers.Adam(), tf.keras.optimizers.RMSprop()]
loss = ['sparse_categorical_crossentropy', 'categorical_crossentropy']
lr = [0.01, 0.1, 0.5]
epo = [5, 20, 50]
bat_size = [64, 128, 256]

# %%
def build_fc_model():
  fc_model = tf.keras.Sequential([
      # First define a Flatten layer
      tf.keras.layers.Flatten(),
      # '''TODO: Define the first fully connected layer. Try different activation functions.'''
      tf.keras.layers.Dense(units= 128, activation=act[0], input_shape = (train_images.shape[1]*train_images.shape[2]*train_images.shape[3],)),
      tf.keras.layers.Dropout(0.5),
      # '''TODO: Define the second Dense layer to output the classification probabilities. Try different activation functions.'''
      tf.keras.layers.Dense(units=10, activation=act[1])
  ])
  return fc_model

# %% [markdown]
# #### Compile the Two-Layer Neural Network

# %% [markdown]
# **TODO**
#
# 1. Try different [optimizers](https://keras.io/api/optimizers/), and report the difference in **accuracy** and plots.
# 2. For each optimizer, try different learning rates and other hyperparameters (If applicable), and report the difference in **accuracy** and plots.
# 3. Try different [loss functions](https://keras.io/api/losses/), and report the difference in **accuracy** and plots.

# %%
fc_model = build_fc_model()

'''TODO: Experiment with different optimizers and learning rates. How do these affect
    the accuracy of the trained model? Which optimizers and/or learning rates yield
    the best performance?'''
fc_model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=lr[2]), 
              loss=loss[0],
              metrics=['accuracy'])

# %% [markdown]
# #### Print the Two-Layer Neural Network Model Summary

# %%
fc_model.build((None, train_images.shape[1], train_images.shape[2], train_images.shape[3]))
fc_model.summary()
# Out:
# Model: "sequential_57"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_57 (Flatten)         (None, 784)               0
# _________________________________________________________________
# dense_170 (Dense)            (None, 128)               100480
# _________________________________________________________________
# dropout_113 (Dropout)        (None, 128)               0
# _________________________________________________________________
# dense_171 (Dense)            (None, 10)                1290
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Train the Two-Layer Neural Network

# %%
BATCH_SIZE = bat_size[1]
EPOCHS = epo[1]

nn_hist = fc_model.fit(train_images, train_labels, validation_data=(val_images, val_labels), batch_size=BATCH_SIZE, epochs=EPOCHS)
# Out:
# Epoch 1/20
# 469/469 [==============================] - 3s 5ms/step - loss: 0.6294 - accuracy: 0.8035 - val_loss: 0.1805 - val_accuracy: 0.9465
# Epoch 2/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2531 - accuracy: 0.9244 - val_loss: 0.1293 - val_accuracy: 0.9628
# Epoch 3/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2088 - accuracy: 0.9359 - val_loss: 0.1128 - val_accuracy: 0.9655
# Epoch 4/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1922 - accuracy: 0.9426 - val_loss: 0.1062 - val_accuracy: 0.9668
# Epoch 5/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1696 - accuracy: 0.9498 - val_loss: 0.0999 - val_accuracy: 0.9702
# Epoch 6/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1605 - accuracy: 0.9511 - val_loss: 0.0976 - val_accuracy: 0.9680
# Epoch 7/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1476 - accuracy: 0.9556 - val_loss: 0.0932 - val_accuracy: 0.9733
# Epoch 8/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1446 - accuracy: 0.9559 - val_loss: 0.0906 - val_accuracy: 0.9721
# Epoch 9/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1391 - accuracy: 0.9574 - val_loss: 0.0872 - val_accuracy: 0.9735
# Epoch 10/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1354 - accuracy: 0.9583 - val_loss: 0.0798 - val_accuracy: 0.9755
# Epoch 11/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1258 - accuracy: 0.9595 - val_loss: 0.0895 - val_accuracy: 0.9720
# Epoch 12/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1235 - accuracy: 0.9609 - val_loss: 0.0825 - val_accuracy: 0.9743
# Epoch 13/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1189 - accuracy: 0.9627 - val_loss: 0.0840 - val_accuracy: 0.9731
# Epoch 14/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1192 - accuracy: 0.9626 - val_loss: 0.0846 - val_accuracy: 0.9754
# Epoch 15/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1109 - accuracy: 0.9646 - val_loss: 0.0783 - val_accuracy: 0.9771
# Epoch 16/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1119 - accuracy: 0.9653 - val_loss: 0.0781 - val_accuracy: 0.9756
# Epoch 17/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1134 - accuracy: 0.9645 - val_loss: 0.0821 - val_accuracy: 0.9749
# Epoch 18/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1109 - accuracy: 0.9649 - val_loss: 0.0779 - val_accuracy: 0.9769
# Epoch 19/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0987 - accuracy: 0.9689 - val_loss: 0.0736 - val_accuracy: 0.9786
# Epoch 20/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1038 - accuracy: 0.9664 - val_loss: 0.0830 - val_accuracy: 0.9764

# %% [markdown]
# #### Plot the Accuracy Curve for the Two-Layer Neural Network

# %%
# Get training and validation accuracy histories
training_acc = nn_hist.history['accuracy']
val_acc = nn_hist.history['val_accuracy']

# Create count of the number of epochs
epoch_count = range(1, EPOCHS + 1)

# Visualize accuracy history
plt.figure()
plt.plot(epoch_count, training_acc, 'r--')
plt.plot(epoch_count, val_acc, 'b-')
plt.legend(['2L NN Training Accuracy', '2L NN Val Accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Two-Layer NN Accuracy')
plt.show()

# %% [markdown]
# #### Evaluate the Two-Layer Neural Network

# %%
val_loss, val_acc = fc_model.evaluate(val_images, val_labels)

print('Validation Accuracy:', val_acc)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0830 - accuracy: 0.9764
# Validation Accuracy: 0.9764000177383423

# %% [markdown]
# ### 2.2.2 Convolutional Neural Network Solution

# %% [markdown]
# Build a CNN, using tf.keras, composed of two convolutional layers and pooling layers, followed by two fully connected layers, and ultimately output a probability distribution over the 10 digit classes (0-9).

# %% [markdown]
# ![CNN Model](https://github.com/KhaledElTahan/DeepLearning/blob/master/Labs/lab2/cnn_model.png?raw=1)

# %% [markdown]
# #### Define the Convolutional Neural Network

# %% [markdown]
# **TODO**
#
# 1. Define the convolutional network exactly as in the previous figure by adding two [dense layers](https://keras.io/api/layers/core_layers/dense/).
# 2. Try different [activation functions](https://keras.io/api/layers/#layer-activations) for both layers (ReLU, Tanh, and other activations for first layer - Softmax, and other activations for output layer), and report the difference in **accuracy** and plots.
# 3. Try different [regularization kernerls](https://keras.io/api/layers/#layer-weight-regularizers), and [regularization layers](https://keras.io/api/layers/#regularization-layers) (L1, L2, Dropout, and other regularizations), and report the difference in **accuracy** and plots.
# 4. Try different [convolution filter sizes](https://keras.io/api/layers/convolution_layers/convolution2d/), and report the difference in accuracy and plots.
# 5. For each convolution filter, try different stride lengthes, and report the difference in accuracy and plots.
# 6. Try different [pooling layers](https://keras.io/api/layers/pooling_layers/) (i.e. change first and second pooling layers into other different pooling layers), and report the difference in accuracy and plots.
#
# **NOTE: Variations for the filter sizes, stride lengths and pooling layers, will mean of course that you will have to use different number of units for the next layers (i.e. you won't stick to the above mentioned figure once you try those variations).**

# %%
act = ['relu','softmax','tanh','sigmoid']
opt = [tf.keras.optimizers.SGD(), tf.keras.optimizers.Adam(), tf.keras.optimizers.RMSprop()]
loss = ['sparse_categorical_crossentropy', 'categorical_crossentropy']
lr = [0.01, 0.1, 0.5]
epo = [5, 20, 50]
bat_size = [64, 128, 256]

# %%
def build_cnn_model():
    cnn_model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(filters=24, kernel_size=(5,5), strides=(1,1), input_shape=(28, 28, 1), activation=act[0]),      

        tf.keras.layers.MaxPooling2D(pool_size=(2,2)),

        #'''TODO: Define the second convolutional layer'''
        tf.keras.layers.Conv2D(filters=36, kernel_size=(5,5), strides=(1,1), input_shape=(28, 28, 1), activation=act[0]),
        #'''TODO: Define the second max pooling layer'''
        tf.keras.layers.MaxPooling2D(pool_size=(2,2)),

        tf.keras.layers.Dropout(0.5),

        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(900, activation=act[0]),
        tf.keras.layers.Dense(128, activation=act[0]),
        tf.keras.layers.Dropout(0.5),

        #'''TODO: Define the last Dense layer'''
        tf.keras.layers.Dense(10, activation=act[1])
    ])
    return cnn_model

# %% [markdown]
# #### Compile the Convolutional Neural Network

# %% [markdown]
# **TODO**
#
# 1. Try different [optimizers](https://keras.io/api/optimizers/), and report the difference in **accuracy** and plots.
# 2. For each optimizer, try different learning rates and other hyperparameters (If applicable), and report the difference in **accuracy** and plots.
# 3. Try different [loss functions](https://keras.io/api/losses/), and report the difference in **accuracy** and plots.

# %%
cnn_model = build_cnn_model()

'''TODO: Experiment with different optimizers and learning rates. How do these affect
    the accuracy of the trained model? Which optimizers and/or learning rates yield
    the best performance?'''
cnn_model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=lr[1]), 
              loss=loss[1],
              metrics=['accuracy'])

# %% [markdown]
# #### Print the Convolutional Neural Network Model Summary

# %%
cnn_model.build((None, train_images.shape[1], train_images.shape[2], train_images.shape[3]))
cnn_model.summary()
# Out:
# Model: "sequential_55"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_110 (Conv2D)          (None, 24, 24, 24)        624
# _________________________________________________________________
# max_pooling2d_94 (MaxPooling (None, 12, 12, 24)        0
# _________________________________________________________________
# conv2d_111 (Conv2D)          (None, 8, 8, 36)          21636
# _________________________________________________________________
# max_pooling2d_95 (MaxPooling (None, 4, 4, 36)          0
# _________________________________________________________________
# dropout_110 (Dropout)        (None, 4, 4, 36)          0
# _________________________________________________________________
# flatten_55 (Flatten)         (None, 576)               0
# _________________________________________________________________
# dense_165 (Dense)            (None, 900)               519300
# _________________________________________________________________
# dense_166 (Dense)            (None, 128)               115328
# _________________________________________________________________
# dropout_111 (Dropout)        (None, 128)               0
# _________________________________________________________________
# dense_167 (Dense)            (None, 10)                1290
# =================================================================
# Total params: 658,178
# Trainable params: 658,178
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Train the Convolutional Neural Network

# %%
BATCH_SIZE = bat_size[1]
EPOCHS = epo[1]

cnn_hist = cnn_model.fit(train_images, y_train, validation_data=(val_images, y_val), batch_size=BATCH_SIZE, epochs=EPOCHS)
# Out:
# Epoch 1/20
# 469/469 [==============================] - 46s 98ms/step - loss: 0.9775 - accuracy: 0.6644 - val_loss: 0.0984 - val_accuracy: 0.9679
# Epoch 2/20
# 469/469 [==============================] - 46s 98ms/step - loss: 0.1999 - accuracy: 0.9401 - val_loss: 0.0603 - val_accuracy: 0.9798
# Epoch 3/20
# 469/469 [==============================] - 46s 98ms/step - loss: 0.1457 - accuracy: 0.9569 - val_loss: 0.0488 - val_accuracy: 0.9849
# Epoch 4/20
# 469/469 [==============================] - 46s 98ms/step - loss: 0.1131 - accuracy: 0.9661 - val_loss: 0.0379 - val_accuracy: 0.9890
# Epoch 5/20
# 469/469 [==============================] - 46s 98ms/step - loss: 0.0980 - accuracy: 0.9712 - val_loss: 0.0334 - val_accuracy: 0.9901
# Epoch 6/20
# 469/469 [==============================] - 46s 98ms/step - loss: 0.0907 - accuracy: 0.9729 - val_loss: 0.0319 - val_accuracy: 0.9911
# Epoch 7/20
# 469/469 [==============================] - 46s 98ms/step - loss: 0.0787 - accuracy: 0.9768 - val_loss: 0.0305 - val_accuracy: 0.9908
# Epoch 8/20
# 469/469 [==============================] - 46s 99ms/step - loss: 0.0734 - accuracy: 0.9784 - val_loss: 0.0278 - val_accuracy: 0.9917
# Epoch 9/20
# 469/469 [==============================] - 46s 98ms/step - loss: 0.0627 - accuracy: 0.9819 - val_loss: 0.0266 - val_accuracy: 0.9913
# Epoch 10/20
# 469/469 [==============================] - 46s 98ms/step - loss: 0.0603 - accuracy: 0.9818 - val_loss: 0.0249 - val_accuracy: 0.9927
# Epoch 11/20
# 469/469 [==============================] - 46s 98ms/step - loss: 0.0574 - accuracy: 0.9823 - val_loss: 0.0265 - val_accuracy: 0.9923
# Epoch 12/20
# 469/469 [==============================] - 46s 98ms/step - loss: 0.0567 - accuracy: 0.9834 - val_loss: 0.0260 - val_accuracy: 0.9918
# Epoch 13/20
# 469/469 [==============================] - 47s 100ms/step - loss: 0.0529 - accuracy: 0.9838 - val_loss: 0.0217 - val_accuracy: 0.9930
# Epoch 14/20
# 469/469 [==============================] - 46s 99ms/step - loss: 0.0501 - accuracy: 0.9846 - val_loss: 0.0226 - val_accuracy: 0.9929
# Epoch 15/20
# 469/469 [==============================] - 46s 99ms/step - loss: 0.0504 - accuracy: 0.9850 - val_loss: 0.0216 - val_accuracy: 0.9931
# Epoch 16/20
# 469/469 [==============================] - 46s 99ms/step - loss: 0.0466 - accuracy: 0.9864 - val_loss: 0.0198 - val_accuracy: 0.9942
# Epoch 17/20
# 469/469 [==============================] - 46s 99ms/step - loss: 0.0427 - accuracy: 0.9872 - val_loss: 0.0213 - val_accuracy: 0.9931
# Epoch 18/20
# 469/469 [==============================] - 46s 99ms/step - loss: 0.0430 - accuracy: 0.9868 - val_loss: 0.0193 - val_accuracy: 0.9939
# Epoch 19/20
# 469/469 [==============================] - 46s 99ms/step - loss: 0.0421 - accuracy: 0.9875 - val_loss: 0.0186 - val_accuracy: 0.9939
# Epoch 20/20
# 469/469 [==============================] - 47s 100ms/step - loss: 0.0389 - accuracy: 0.9881 - val_loss: 0.0197 - val_accuracy: 0.9934

# %% [markdown]
# #### Plot the Accuracy Curve for the Convolutional Neural Network

# %%
# Get training and validation accuracy histories
training_acc = cnn_hist.history['accuracy']
val_acc = cnn_hist.history['val_accuracy']

# Create count of the number of epochs
epoch_count = range(1, EPOCHS + 1)

# Visualize accuracy history
plt.figure()
plt.plot(epoch_count, training_acc, 'r--')
plt.plot(epoch_count, val_acc, 'b-')
plt.legend(['CNN Training Accuracy', 'CNN Val Accuracy'])
plt.xlabel('Epoch')
plt.ylabel('CNN Accuracy')
plt.show()

# %% [markdown]
# #### Evaluate the Convolutional Neural Network

# %%
val_loss, val_acc = cnn_model.evaluate(val_images, y_val)

print('Validation Accuracy:', val_acc)
# Out:
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0197 - accuracy: 0.9934
# Validation Accuracy: 0.993399977684021

# %% [markdown]
# ### One Final Question

# %% [markdown]
# What is the highest accuracy you’re able to achieve using the CNN model, and how does the accuracy of the CNN model compare to the accuracy of the simple fully connected network?

# %% [markdown]
# **Answer**
# *   The heighest accuracy achieved using CNN --> 0.9940
# *   Comparsion between FCNN & CNN:
#
# **Model** → (activation 1, activation 2, regularization, optimizer, loss function)
#
# **Hyperparameters** → (learning rate, number of epochs, batch size)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2.3 Conclusion

# %% [markdown]
# That's it! Congratulations on training a multinominal classification models.
#
# Make sure you deliver all the requirements for the submission.
